# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject</div>
# <span style="">MicroProject: World University Rankings</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/world-university-rankings/">https://discovery.cs.illinois.edu/microproject/world-university-rankings/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Data Source: The Times Higher Education
#
# There are hundreds of organizations that rank universities, including US News and World Report, QS World University Rankings, Times Higher Education (THE), and many others.
#
# The Times Higher Education (THE) provides a clean, well-documented CSV that includes their rankings based on the "performance data on universities for students and their families, academics, university leaders, governments and industry".  Their 2020 dataset includes almost 1,400 universities across 92 countries and includes 13 performance indicators that measure an institution’s performance across teaching, research, knowledge transfer and international outlook.  Their website with additional details on this dataset is found here: https://www.timeshighereducation.com/content/world-university-rankings
#
# In this MicroProject, you will explore basic DataFrame operations on the Times Higher Education university rankings.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Importing the World University Rank Dataset
#
# To use the `pandas` library, we must **import** it into your notebook. import pandas as `pd` in the following cell:

# %%
import pandas as pd

# %% [markdown]
# Use panda's `read_csv` function to read the `World_University_Rank_2020.csv` (already provided for you) and store that data into a DataFrame called `df`:

# %%
# Read the CSV into a new DataFrame `df`:
df = pd.read_csv("World_University_Rank_2020.csv")
df
# Out:
#       Score_Rank                                      University  \
# 0              1                            University of Oxford
# 1              2              California Institute of Technology
# 2              3                         University of Cambridge
# 3              4                             Stanford University
# 4              5           Massachusetts Institute of Technology
# ...          ...                                             ...
# 1391         531                          Cear� State University
# 1392         532  Pontifical Catholic University of Minas Gerais
# 1393         533                        Bashkir State University
# 1394         534                     University of Caxias do Sul
# 1395         535                          Tokyo Denki University
#
#                  Country  Number_students  Numb_students_per_Staff  \
# 0         United Kingdom            20664                     11.2
# 1          United States             2240                      6.4
# 2         United Kingdom            18978                     10.9
# 3          United States            16135                      7.3
# 4          United States            11247                      8.6
# ...                  ...              ...                      ...
# 1391              Brazil            20174                     17.8
# 1392              Brazil            34101                     21.3
# 1393  Russian Federation            15236                     11.1
# 1394              Brazil            17101                     24.9
# 1395               Japan             9285                     25.6
#
#      International_Students Percentage_Female Percentage_Male  Teaching  \
# 0                       41%               46%             54%      90.5
# 1                       30%               34%             66%      92.1
# 2                       37%               47%             53%      91.4
# 3                       23%               43%             57%      92.8
# 4                       34%               39%             61%      90.5
# ...                     ...               ...             ...       ...
# 1391                     0%               55%             45%      16.2
# 1392                     0%               57%             43%      15.3
# 1393                     3%               63%             37%      17.0
# 1394                     0%               54%             46%      13.8
# 1395                     2%               12%             88%      15.2
#
#       Research  Citations  Industry_Income  International_Outlook  \
# 0         99.6       98.4             65.5                   96.4
# 1         97.2       97.9             88.0                   82.5
# 2         98.7       95.8             59.3                   95.0
# 3         96.4       99.9             66.2                   79.5
# 4         92.4       99.5             86.9                   89.0
# ...        ...        ...              ...                    ...
# 1391       8.3        6.1             35.6                   16.3
# 1392       7.7        6.7             35.1                   19.4
# 1393       8.1        4.5             36.9                   16.7
# 1394       7.8        7.6             35.0                   17.7
# 1395       9.3        3.4             39.6                   17.7
#
#       Score_Result Overall_Ranking
# 0             95.4           95.40
# 1             94.5           94.50
# 2             94.4           94.40
# 3             94.3           94.30
# 4             93.6           93.60
# ...            ...             ...
# 1391          11.3       10.7�22.1
# 1392          11.2       10.7�22.1
# 1393          11.1       10.7�22.1
# 1394          11.0       10.7�22.1
# 1395          10.7       10.7�22.1
#
# [1396 rows x 15 columns]

# %%
### TEST CASE for Importing the World University Rank Dataset
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert("df" in vars()), "Make sure to name the dataframe df"
assert(df["University"].iloc[0] == "University of Oxford")
assert(df["University"].iloc[1392] == "Pontifical Catholic University of Minas Gerais")
assert("University" in df)
assert("Score" not in df)
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Rankings with the United States
#
# In this dataset, each row represents one university.
#
# Find the variable that encodes where the university is located.  Using a conditional, create a new DataFrame called `df_US` that includes the subset of data containing only the universities in the United States:

# %%
df_US = df[df["Country"] == "United States"]
df_US
# Out:
#       Score_Rank                               University        Country  \
# 1              2       California Institute of Technology  United States
# 3              4                      Stanford University  United States
# 4              5    Massachusetts Institute of Technology  United States
# 5              6                     Princeton University  United States
# 6              7                       Harvard University  United States
# ...          ...                                      ...            ...
# 1011         428                       Oakland University  United States
# 1015         429  California State University, Long Beach  United States
# 1048         437              University of North Florida  United States
# 1052         438                   Texas State University  United States
# 1212         477  University of North Carolina Wilmington  United States
#
#       Number_students  Numb_students_per_Staff International_Students  \
# 1                2240                      6.4                    30%
# 3               16135                      7.3                    23%
# 4               11247                      8.6                    34%
# 5                7983                      8.1                    25%
# 6               20823                      9.2                    24%
# ...               ...                      ...                    ...
# 1011            15887                     18.9                     4%
# 1015            30595                     19.7                     4%
# 1048            12132                     17.7                     2%
# 1052            31893                     19.1                     1%
# 1212            14791                     19.6                     2%
#
#      Percentage_Female Percentage_Male  Teaching  Research  Citations  \
# 1                  34%             66%      92.1      97.2       97.9
# 3                  43%             57%      92.8      96.4       99.9
# 4                  39%             61%      90.5      92.4       99.5
# 5                  45%             55%      90.3      96.3       98.8
# 6                  49%             51%      89.2      98.6       99.1
# ...                ...             ...       ...       ...        ...
# 1011               57%             43%      25.5      12.7       24.5
# 1015               58%             42%      23.1      10.1       27.3
# 1048               57%             43%      24.8      10.5       25.7
# 1052               58%             42%      17.4      14.3       27.3
# 1212               62%             38%      15.9       7.7       23.3
#
#       Industry_Income  International_Outlook  Score_Result Overall_Ranking
# 1                88.0                   82.5          94.5           94.50
# 3                66.2                   79.5          94.3           94.30
# 4                86.9                   89.0          93.6           93.60
# 5                58.6                   81.1          93.2           93.20
# 6                47.3                   76.3          93.0           93.00
# ...               ...                    ...           ...             ...
# 1011             35.3                   28.9          21.9       10.7�22.1
# 1015             35.9                   37.3          21.8       10.7�22.1
# 1048             34.6                   24.0          21.0       10.7�22.1
# 1052             36.4                   30.4          20.9       10.7�22.1
# 1212             35.1                   26.5          16.9       10.7�22.1
#
# [172 rows x 15 columns]

# %%
### TEST CASE for Puzzle 1: Rankings with the United States
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert(df.iloc[47]["University"] == "University of Illinois at Urbana-Champaign")
assert(df.iloc[47]["Number_students"] == 44916)

assert('df_US' in vars()), "Make sure to name the dataframe df_US."
assert(len(df_US) == 172), "It looks like you did not subset df_US to only include universities located in the United States."
assert(df_US["University"].iloc[0] == "California Institute of Technology")
assert(df_US["Number_students"].iloc[171] == 14791)

print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# ## **Key Idea**: Indexes

# %% [markdown]
# By default, pandas creates an **index column** that will always start with the index `0`.  Each row after the first receives an index in an increasing order (the second row has index `1`, the third row index `2`, and so on).
#
# The Top University in the full original dataset, Oxford, has an index of 0.  Using the full original dataset (`df`), `df.loc[0]` will display the row at the index (or `loc`) `0`.  See this yourself in running the following code:

# %%
# Find the row with the index `0` in the DataFrame `df`:
df.loc[0]
# Out:
# Score_Rank                                    1
# University                 University of Oxford
# Country                          United Kingdom
# Number_students                           20664
# Numb_students_per_Staff                    11.2
# International_Students                      41%
# Percentage_Female                           46%
# Percentage_Male                             54%
# Teaching                                   90.5
# Research                                   99.6
# Citations                                  98.4
# Industry_Income                            65.5
# International_Outlook                      96.4
# Score_Result                               95.4
# Overall_Ranking                           95.40
# Name: 0, dtype: object

# %% [markdown]
# ### Indexes after Row Selection
#
# Our dataset of US-based universities -- `df_US` -- is a subset of the original full dataset and **still has the original index values**.
#
# When we attempt to find index `0` of `df_US`, we **expect to get a `KeyError`** indicating that this index does NOT exist within `df_US`.  Try this yourself:

# %%
# Find the row with the index `0` in the DataFrame `df_US`:
#          ** An error in expected!! **
#   ** (You will fix it in the next section.) **
df_US.head(1)
# Out:
#    Score_Rank                          University        Country  \
# 1           2  California Institute of Technology  United States
#
#    Number_students  Numb_students_per_Staff International_Students  \
# 1             2240                      6.4                    30%
#
#   Percentage_Female Percentage_Male  Teaching  Research  Citations  \
# 1               34%             66%      92.1      97.2       97.9
#
#    Industry_Income  International_Outlook  Score_Result Overall_Ranking
# 1             88.0                   82.5          94.5           94.50

# %% [markdown]
# ### Fix The KeyError
#
# (⚠️ You **MUST** make the fix for grading to work, it's easy to miss this section! ⚠️)
#
# In the above cell, fix the error by updating the code to select the best University in `df_US`.
#
# Fix it and re-run the cell before you continue to the next puzzle. :)

# %% [markdown]
# <hr style="color: #DD3403; border-style: dashed;">

# %% [markdown]
# ## Puzzle 1.2: Re-indexing the Universities in the United States
#
# The command `df_US.reset_index()` can be used to **regenerate** the indexes for `df_US`.
#
# When you run `reset_index`, the pandas library will:
# 1. Move the existing indexes to a new column called `index`
# 2. Then, replace all of the indexes in `df_US` with a new index (starting with `0`, and counting up by one for each row, just like it was a new dataset)
#
# Use the `reset_index()` function on `df_US` to reset the indexes:

# %%
df_US = df_US.reset_index()
df_US
# Out:
#      index  Score_Rank                               University  \
# 0        1           2       California Institute of Technology
# 1        3           4                      Stanford University
# 2        4           5    Massachusetts Institute of Technology
# 3        5           6                     Princeton University
# 4        6           7                       Harvard University
# ..     ...         ...                                      ...
# 167   1011         428                       Oakland University
# 168   1015         429  California State University, Long Beach
# 169   1048         437              University of North Florida
# 170   1052         438                   Texas State University
# 171   1212         477  University of North Carolina Wilmington
#
#            Country  Number_students  Numb_students_per_Staff  \
# 0    United States             2240                      6.4
# 1    United States            16135                      7.3
# 2    United States            11247                      8.6
# 3    United States             7983                      8.1
# 4    United States            20823                      9.2
# ..             ...              ...                      ...
# 167  United States            15887                     18.9
# 168  United States            30595                     19.7
# 169  United States            12132                     17.7
# 170  United States            31893                     19.1
# 171  United States            14791                     19.6
#
#     International_Students Percentage_Female Percentage_Male  Teaching  \
# 0                      30%               34%             66%      92.1
# 1                      23%               43%             57%      92.8
# 2                      34%               39%             61%      90.5
# 3                      25%               45%             55%      90.3
# 4                      24%               49%             51%      89.2
# ..                     ...               ...             ...       ...
# 167                     4%               57%             43%      25.5
# 168                     4%               58%             42%      23.1
# 169                     2%               57%             43%      24.8
# 170                     1%               58%             42%      17.4
# 171                     2%               62%             38%      15.9
#
#      Research  Citations  Industry_Income  International_Outlook  \
# 0        97.2       97.9             88.0                   82.5
# 1        96.4       99.9             66.2                   79.5
# 2        92.4       99.5             86.9                   89.0
# 3        96.3       98.8             58.6                   81.1
# 4        98.6       99.1             47.3                   76.3
# ..        ...        ...              ...                    ...
# 167      12.7       24.5             35.3                   28.9
# 168      10.1       27.3             35.9                   37.3
# 169      10.5       25.7             34.6                   24.0
# 170      14.3       27.3             36.4                   30.4
# 171       7.7       23.3             35.1                   26.5
#
#      Score_Result Overall_Ranking
# 0            94.5           94.50
# 1            94.3           94.30
# 2            93.6           93.60
# 3            93.2           93.20
# 4            93.0           93.00
# ..            ...             ...
# 167          21.9       10.7�22.1
# 168          21.8       10.7�22.1
# 169          21.0       10.7�22.1
# 170          20.9       10.7�22.1
# 171          16.9       10.7�22.1
#
# [172 rows x 16 columns]

# %%
### TEST CASE for Puzzle 1.2: Re-indexing the universities in the United States
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"
assert(df_US["University"].loc[0] == "California Institute of Technology")
assert("index" in df_US.columns)
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 2: Large Universities in the United States
#
# In the United States, there are generally large universities (often "large state schools") and small universities (often "small liberal arts colleges").  Explore the dataset and find the variable that stores the number of students that attends each university.
#
# For the next analysis, we want to focus only on **large universities in the United States**.  For the purpose of this analysis, we'll refer to any University with at least 30,000 students as "large".
#
# Create a new DataFrame called `df_US_large`, which contains all large universities in the United States:

# %%
df_US_large = df[(df["Country"] == "United States") & (df["Number_students"] >= 30000)]

df_US_large
# Out:
#       Score_Rank                                         University  \
# 12            13                 University of California, Berkeley
# 16            16              University of California, Los Angeles
# 20            20                   University of Michigan-Ann Arbor
# 25            25                           University of Washington
# 28            27                                New York University
# 30            29                University of California, San Diego
# 39            34                      University of Texas at Austin
# 47            41         University of Illinois at Urbana-Champaign
# 50            44                    University of Wisconsin-Madison
# 53            47        University of North Carolina at Chapel Hill
# 54            48                    University of California, Davis
# 62            53                  University of Southern California
# 69            59                Ohio State University (Main campus)
# 77            65                           Penn State (Main campus)
# 78            66                            University of Minnesota
# 83            68                          Michigan State University
# 87            71                   Purdue University West Lafayette
# 90            73               University of Maryland, College Park
# 95            77                   University of California, Irvine
# 103           81                              University of Arizona
# 123           94                     University of Colorado Boulder
# 133          101                                 Indiana University
# 154          111                   Arizona State University (Tempe)
# 169          117        Rutgers, the State University of New Jersey
# 174          121                              University of Florida
# 177          122                               Texas A&M University
# 209          137                        University of Massachusetts
# 217          144                University of South Florida (Tampa)
# 220          146                                 University of Utah
# 243          157  Virginia Polytechnic Institute and State Unive...
# 277          175                           Florida State University
# 310          194                    North Carolina State University
# 312          195                                  Temple University
# 393          230                          University of Connecticut
# 400          233                              Iowa State University
# 403          234                              University of Georgia
# 431          246                              University of Alabama
# 440          248              University of South Carolina-Columbia
# 478          262                              University of Houston
# 507          271                   Florida International University
# 558          290                         San Diego State University
# 609          304                      University of Central Florida
# 638          314                              Texas Tech University
# 1015         429            California State University, Long Beach
# 1052         438                             Texas State University
#
#             Country  Number_students  Numb_students_per_Staff  \
# 12    United States            41081                     13.7
# 16    United States            41066                      9.4
# 20    United States            42982                      8.3
# 25    United States            45692                     11.1
# 28    United States            44466                      8.9
# 30    United States            33579                     13.0
# 39    United States            49165                     17.2
# 47    United States            44916                     17.9
# 50    United States            39154                     10.0
# 53    United States            35419                      9.4
# 54    United States            39164                     12.0
# 62    United States            36929                     11.7
# 69    United States            54372                     12.5
# 77    United States            46204                     15.3
# 78    United States            61120                     12.4
# 83    United States            44789                     16.5
# 87    United States            40451                     15.7
# 90    United States            33108                     16.6
# 95    United States            32706                     16.5
# 103   United States            39124                     18.4
# 123   United States            33186                     16.3
# 133   United States            66872                     13.6
# 154   United States            46683                     21.1
# 169   United States            44801                     11.2
# 174   United States            46642                     16.8
# 177   United States            60818                     24.8
# 209   United States            61204                     13.0
# 217   United States            33885                     18.9
# 220   United States            30365                     14.2
# 243   United States            32838                     18.3
# 277   United States            38520                     24.1
# 310   United States            30231                     12.5
# 312   United States            35814                     13.0
# 393   United States            32446                     15.2
# 400   United States            32469                     18.8
# 403   United States            35164                     16.3
# 431   United States            35120                     22.5
# 440   United States            32291                     16.2
# 478   United States            44128                     25.7
# 507   United States            34203                     23.8
# 558   United States            30799                     30.5
# 609   United States            56228                     35.3
# 638   United States            33015                     20.6
# 1015  United States            30595                     19.7
# 1052  United States            31893                     19.1
#
#      International_Students Percentage_Female Percentage_Male  Teaching  \
# 12                      17%               50%             50%      83.0
# 16                      17%               54%             46%      83.1
# 20                      17%               49%             51%      79.4
# 25                      16%               53%             47%      72.2
# 28                      33%               57%             43%      76.8
# 30                      23%               46%             54%      62.6
# 39                      10%               52%             48%      68.2
# 47                      24%               47%             53%      63.2
# 50                      13%                0%              0%      68.8
# 53                       8%               57%             43%      59.7
# 54                      14%               58%             42%      62.4
# 62                      25%               53%             47%      54.7
# 69                      13%               50%             50%      57.5
# 77                      16%               46%             54%      55.2
# 78                      11%               52%             48%      55.2
# 83                      16%               51%             49%      56.6
# 87                      23%               43%             57%      57.5
# 90                      11%               48%             52%      46.9
# 95                      26%               52%             48%      43.3
# 103                     10%               52%             48%      52.6
# 123                     11%               44%             56%      44.8
# 133                     15%               52%             48%      50.8
# 154                     21%               43%             57%      39.3
# 169                     17%               52%             48%      47.8
# 174                     10%               55%             45%      54.0
# 177                      8%               47%             53%      49.3
# 209                     15%               48%             52%      38.5
# 217                     14%                0%              0%      30.5
# 220                      8%               47%             53%      39.0
# 243                     14%               43%             57%      37.5
# 277                      7%               56%             44%      38.0
# 310                     15%               45%             55%      36.7
# 312                      9%               53%             47%      39.3
# 393                      9%               53%             47%      36.5
# 400                     12%               44%             56%      29.5
# 403                      7%               57%             43%      34.9
# 431                      4%               56%             44%      26.9
# 440                      5%               55%             45%      33.2
# 478                      9%               50%             50%      33.6
# 507                      8%               57%             43%      30.4
# 558                      8%               55%             45%      23.7
# 609                      4%               56%             44%      26.5
# 638                      9%               46%             54%      30.8
# 1015                     4%               58%             42%      23.1
# 1052                     1%               58%             42%      17.4
#
#       Research  Citations  Industry_Income  International_Outlook  \
# 12        90.6       99.2             46.1                   70.4
# 16        88.6       97.3             51.3                   64.1
# 20        86.1       94.9             47.7                   59.2
# 25        82.2       98.6             47.5                   60.4
# 28        77.5       96.5             38.7                   65.4
# 30        78.9       97.7             90.3                   63.7
# 39        76.2       93.2             46.6                   39.1
# 47        78.0       84.4             47.9                   54.3
# 50        70.3       85.3             46.3                   47.4
# 53        63.2       96.9             43.9                   38.0
# 54        66.9       83.2             51.4                   62.4
# 62        59.3       93.1             39.7                   66.2
# 69        56.1       87.3             53.3                   59.5
# 77        67.1       75.7             52.1                   47.4
# 78        59.3       82.7             78.2                   40.2
# 83        57.4       80.0             37.8                   63.3
# 87        66.4       63.0             64.3                   72.0
# 90        59.1       89.6             39.2                   41.2
# 95        46.5       94.9             58.9                   71.9
# 103       53.7       85.3             52.7                   40.2
# 123       45.6       93.1             41.7                   47.3
# 133       49.7       76.7             49.8                   53.5
# 154       50.7       81.6             38.5                   61.8
# 169       48.5       73.9             41.1                   51.5
# 174       53.8       61.9             57.9                   40.0
# 177       54.8       62.8             45.3                   54.3
# 209       31.1       87.0             49.9                   61.7
# 217       34.2       87.3             89.0                   54.7
# 220       34.7       86.4             48.3                   33.0
# 243       42.3       70.9             47.5                   54.0
# 277       40.1       69.2             39.4                   43.5
# 310       35.3       64.7             43.2                   57.8
# 312       23.5       79.3             34.4                   37.7
# 393       29.7       60.6             37.9                   49.0
# 400       33.0       60.5             49.6                   56.7
# 403       35.8       55.8             37.2                   46.0
# 431       22.4       77.4             35.3                   28.9
# 440       25.5       63.7             36.2                   43.2
# 478       25.9       58.0             36.8                   42.5
# 507       22.6       62.3             38.0                   39.7
# 558       24.4       62.0             35.1                   33.9
# 609       28.7       49.7             42.6                   32.9
# 638       20.9       46.5             36.2                   48.4
# 1015      10.1       27.3             35.9                   37.3
# 1052      14.3       27.3             36.4                   30.4
#
#       Score_Result Overall_Ranking
# 12            88.3           88.30
# 16            86.8           86.80
# 20            83.8           83.80
# 25            81.6           81.60
# 28            81.1           81.10
# 30            78.8           78.80
# 39            75.4           75.40
# 47            73.0           72.90
# 50            72.0           72.00
# 53            69.9           69.90
# 54            69.7           69.70
# 62            68.1           68.10
# 69            66.1           66.10
# 77            64.3           64.20
# 78            64.1           64.10
# 83            63.9           63.90
# 87            63.1           63.10
# 90            62.8           62.70
# 95            62.3           62.30
# 103           61.8           61.80
# 123           59.6           59.60
# 133           58.4           58.40
# 154           57.1           57.10
# 169           56.0           56.00
# 174           55.4           55.40
# 177           55.3           55.30
# 209           52.9       50.1�53.7
# 217           51.9       50.1�53.7
# 220           51.7       50.1�53.7
# 243           50.4       50.1�53.7
# 277           48.4       46.9�50.0
# 310           46.4       44.5�46.8
# 312           46.3       44.5�46.8
# 393           42.7       42.4�44.4
# 400           42.4       42.4�44.4
# 403           42.3       38.8�42.3
# 431           41.1       38.8�42.3
# 440           40.9       38.8�42.3
# 478           39.4       38.8�42.3
# 507           38.5       35.3�38.7
# 558           36.5       35.3�38.7
# 609           35.0       28.3�35.2
# 638           34.0       28.3�35.2
# 1015          21.8       10.7�22.1
# 1052          20.9       10.7�22.1

# %%
### TEST CASE for Puzzle 2: Large universities in the United States
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert('df_US_large' in vars()), "Make sure to name the dataframe df_US_large."
assert(len(df_US_large) == 45), "It looks like you did not subset df_US_large to only universities with at least 30000 students."
assert(df_US_large["University"].iloc[7] == "University of Illinois at Urbana-Champaign")
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# ## Puzzle 2.2: Creating a Ranking List of Large US Universities
#
# In the THE dataset, the dataset provides a `Score_Rank` column that contains the global rank of each school. For our analysis, we want to add a new column called `US_Large_Rank` that contains the ranking of large schools in the United States.  There are several ways to do this, but one of the easiest is to use the `reset_index()` function.
#
# There's three observations we can make:
#
# - Since the list is already sorted, we know the first university in `df_US_large` is the top university (Rank #1).  The second row is Rank #2, and so on.
# - If we use `reset_index`, pandas will re-index the rows starting from zero.
# - The first row is index 0, which will be Rank #1, so we'd just need to add one to all the index values!
#
# Complete the following two steps:
# 1. Use `reset_index()` to reset the index values of `df_US_large`,
# 2. Then, create a new column in `df_US_large` called `"US_Large_Rank"` with the value: `df_US_large.index + 1`.

# %%
# Step 1: Reset the index of df_US_large (if needed, see Puzzle 1.2 to refresh how you can do this):
df_US_large = df_US_large.reset_index()
df_US_large
# Out:
#     index  Score_Rank                                         University  \
# 0      12          13                 University of California, Berkeley
# 1      16          16              University of California, Los Angeles
# 2      20          20                   University of Michigan-Ann Arbor
# 3      25          25                           University of Washington
# 4      28          27                                New York University
# 5      30          29                University of California, San Diego
# 6      39          34                      University of Texas at Austin
# 7      47          41         University of Illinois at Urbana-Champaign
# 8      50          44                    University of Wisconsin-Madison
# 9      53          47        University of North Carolina at Chapel Hill
# 10     54          48                    University of California, Davis
# 11     62          53                  University of Southern California
# 12     69          59                Ohio State University (Main campus)
# 13     77          65                           Penn State (Main campus)
# 14     78          66                            University of Minnesota
# 15     83          68                          Michigan State University
# 16     87          71                   Purdue University West Lafayette
# 17     90          73               University of Maryland, College Park
# 18     95          77                   University of California, Irvine
# 19    103          81                              University of Arizona
# 20    123          94                     University of Colorado Boulder
# 21    133         101                                 Indiana University
# 22    154         111                   Arizona State University (Tempe)
# 23    169         117        Rutgers, the State University of New Jersey
# 24    174         121                              University of Florida
# 25    177         122                               Texas A&M University
# 26    209         137                        University of Massachusetts
# 27    217         144                University of South Florida (Tampa)
# 28    220         146                                 University of Utah
# 29    243         157  Virginia Polytechnic Institute and State Unive...
# 30    277         175                           Florida State University
# 31    310         194                    North Carolina State University
# 32    312         195                                  Temple University
# 33    393         230                          University of Connecticut
# 34    400         233                              Iowa State University
# 35    403         234                              University of Georgia
# 36    431         246                              University of Alabama
# 37    440         248              University of South Carolina-Columbia
# 38    478         262                              University of Houston
# 39    507         271                   Florida International University
# 40    558         290                         San Diego State University
# 41    609         304                      University of Central Florida
# 42    638         314                              Texas Tech University
# 43   1015         429            California State University, Long Beach
# 44   1052         438                             Texas State University
#
#           Country  Number_students  Numb_students_per_Staff  \
# 0   United States            41081                     13.7
# 1   United States            41066                      9.4
# 2   United States            42982                      8.3
# 3   United States            45692                     11.1
# 4   United States            44466                      8.9
# 5   United States            33579                     13.0
# 6   United States            49165                     17.2
# 7   United States            44916                     17.9
# 8   United States            39154                     10.0
# 9   United States            35419                      9.4
# 10  United States            39164                     12.0
# 11  United States            36929                     11.7
# 12  United States            54372                     12.5
# 13  United States            46204                     15.3
# 14  United States            61120                     12.4
# 15  United States            44789                     16.5
# 16  United States            40451                     15.7
# 17  United States            33108                     16.6
# 18  United States            32706                     16.5
# 19  United States            39124                     18.4
# 20  United States            33186                     16.3
# 21  United States            66872                     13.6
# 22  United States            46683                     21.1
# 23  United States            44801                     11.2
# 24  United States            46642                     16.8
# 25  United States            60818                     24.8
# 26  United States            61204                     13.0
# 27  United States            33885                     18.9
# 28  United States            30365                     14.2
# 29  United States            32838                     18.3
# 30  United States            38520                     24.1
# 31  United States            30231                     12.5
# 32  United States            35814                     13.0
# 33  United States            32446                     15.2
# 34  United States            32469                     18.8
# 35  United States            35164                     16.3
# 36  United States            35120                     22.5
# 37  United States            32291                     16.2
# 38  United States            44128                     25.7
# 39  United States            34203                     23.8
# 40  United States            30799                     30.5
# 41  United States            56228                     35.3
# 42  United States            33015                     20.6
# 43  United States            30595                     19.7
# 44  United States            31893                     19.1
#
#    International_Students Percentage_Female Percentage_Male  Teaching  \
# 0                     17%               50%             50%      83.0
# 1                     17%               54%             46%      83.1
# 2                     17%               49%             51%      79.4
# 3                     16%               53%             47%      72.2
# 4                     33%               57%             43%      76.8
# 5                     23%               46%             54%      62.6
# 6                     10%               52%             48%      68.2
# 7                     24%               47%             53%      63.2
# 8                     13%                0%              0%      68.8
# 9                      8%               57%             43%      59.7
# 10                    14%               58%             42%      62.4
# 11                    25%               53%             47%      54.7
# 12                    13%               50%             50%      57.5
# 13                    16%               46%             54%      55.2
# 14                    11%               52%             48%      55.2
# 15                    16%               51%             49%      56.6
# 16                    23%               43%             57%      57.5
# 17                    11%               48%             52%      46.9
# 18                    26%               52%             48%      43.3
# 19                    10%               52%             48%      52.6
# 20                    11%               44%             56%      44.8
# 21                    15%               52%             48%      50.8
# 22                    21%               43%             57%      39.3
# 23                    17%               52%             48%      47.8
# 24                    10%               55%             45%      54.0
# 25                     8%               47%             53%      49.3
# 26                    15%               48%             52%      38.5
# 27                    14%                0%              0%      30.5
# 28                     8%               47%             53%      39.0
# 29                    14%               43%             57%      37.5
# 30                     7%               56%             44%      38.0
# 31                    15%               45%             55%      36.7
# 32                     9%               53%             47%      39.3
# 33                     9%               53%             47%      36.5
# 34                    12%               44%             56%      29.5
# 35                     7%               57%             43%      34.9
# 36                     4%               56%             44%      26.9
# 37                     5%               55%             45%      33.2
# 38                     9%               50%             50%      33.6
# 39                     8%               57%             43%      30.4
# 40                     8%               55%             45%      23.7
# 41                     4%               56%             44%      26.5
# 42                     9%               46%             54%      30.8
# 43                     4%               58%             42%      23.1
# 44                     1%               58%             42%      17.4
#
#     Research  Citations  Industry_Income  International_Outlook  Score_Result  \
# 0       90.6       99.2             46.1                   70.4          88.3
# 1       88.6       97.3             51.3                   64.1          86.8
# 2       86.1       94.9             47.7                   59.2          83.8
# 3       82.2       98.6             47.5                   60.4          81.6
# 4       77.5       96.5             38.7                   65.4          81.1
# 5       78.9       97.7             90.3                   63.7          78.8
# 6       76.2       93.2             46.6                   39.1          75.4
# 7       78.0       84.4             47.9                   54.3          73.0
# 8       70.3       85.3             46.3                   47.4          72.0
# 9       63.2       96.9             43.9                   38.0          69.9
# 10      66.9       83.2             51.4                   62.4          69.7
# 11      59.3       93.1             39.7                   66.2          68.1
# 12      56.1       87.3             53.3                   59.5          66.1
# 13      67.1       75.7             52.1                   47.4          64.3
# 14      59.3       82.7             78.2                   40.2          64.1
# 15      57.4       80.0             37.8                   63.3          63.9
# 16      66.4       63.0             64.3                   72.0          63.1
# 17      59.1       89.6             39.2                   41.2          62.8
# 18      46.5       94.9             58.9                   71.9          62.3
# 19      53.7       85.3             52.7                   40.2          61.8
# 20      45.6       93.1             41.7                   47.3          59.6
# 21      49.7       76.7             49.8                   53.5          58.4
# 22      50.7       81.6             38.5                   61.8          57.1
# 23      48.5       73.9             41.1                   51.5          56.0
# 24      53.8       61.9             57.9                   40.0          55.4
# 25      54.8       62.8             45.3                   54.3          55.3
# 26      31.1       87.0             49.9                   61.7          52.9
# 27      34.2       87.3             89.0                   54.7          51.9
# 28      34.7       86.4             48.3                   33.0          51.7
# 29      42.3       70.9             47.5                   54.0          50.4
# 30      40.1       69.2             39.4                   43.5          48.4
# 31      35.3       64.7             43.2                   57.8          46.4
# 32      23.5       79.3             34.4                   37.7          46.3
# 33      29.7       60.6             37.9                   49.0          42.7
# 34      33.0       60.5             49.6                   56.7          42.4
# 35      35.8       55.8             37.2                   46.0          42.3
# 36      22.4       77.4             35.3                   28.9          41.1
# 37      25.5       63.7             36.2                   43.2          40.9
# 38      25.9       58.0             36.8                   42.5          39.4
# 39      22.6       62.3             38.0                   39.7          38.5
# 40      24.4       62.0             35.1                   33.9          36.5
# 41      28.7       49.7             42.6                   32.9          35.0
# 42      20.9       46.5             36.2                   48.4          34.0
# 43      10.1       27.3             35.9                   37.3          21.8
# 44      14.3       27.3             36.4                   30.4          20.9
#
#    Overall_Ranking
# 0            88.30
# 1            86.80
# 2            83.80
# 3            81.60
# 4            81.10
# 5            78.80
# 6            75.40
# 7            72.90
# 8            72.00
# 9            69.90
# 10           69.70
# 11           68.10
# 12           66.10
# 13           64.20
# 14           64.10
# 15           63.90
# 16           63.10
# 17           62.70
# 18           62.30
# 19           61.80
# 20           59.60
# 21           58.40
# 22           57.10
# 23           56.00
# 24           55.40
# 25           55.30
# 26       50.1�53.7
# 27       50.1�53.7
# 28       50.1�53.7
# 29       50.1�53.7
# 30       46.9�50.0
# 31       44.5�46.8
# 32       44.5�46.8
# 33       42.4�44.4
# 34       42.4�44.4
# 35       38.8�42.3
# 36       38.8�42.3
# 37       38.8�42.3
# 38       38.8�42.3
# 39       35.3�38.7
# 40       35.3�38.7
# 41       28.3�35.2
# 42       28.3�35.2
# 43       10.7�22.1
# 44       10.7�22.1

# %%
# Step 2: Create a new column in df_US_large:
df_US_large["US_large_rank"] = df_US_large.index + 1
df_US_large
# Out:
#     index  Score_Rank                                         University  \
# 0      12          13                 University of California, Berkeley
# 1      16          16              University of California, Los Angeles
# 2      20          20                   University of Michigan-Ann Arbor
# 3      25          25                           University of Washington
# 4      28          27                                New York University
# 5      30          29                University of California, San Diego
# 6      39          34                      University of Texas at Austin
# 7      47          41         University of Illinois at Urbana-Champaign
# 8      50          44                    University of Wisconsin-Madison
# 9      53          47        University of North Carolina at Chapel Hill
# 10     54          48                    University of California, Davis
# 11     62          53                  University of Southern California
# 12     69          59                Ohio State University (Main campus)
# 13     77          65                           Penn State (Main campus)
# 14     78          66                            University of Minnesota
# 15     83          68                          Michigan State University
# 16     87          71                   Purdue University West Lafayette
# 17     90          73               University of Maryland, College Park
# 18     95          77                   University of California, Irvine
# 19    103          81                              University of Arizona
# 20    123          94                     University of Colorado Boulder
# 21    133         101                                 Indiana University
# 22    154         111                   Arizona State University (Tempe)
# 23    169         117        Rutgers, the State University of New Jersey
# 24    174         121                              University of Florida
# 25    177         122                               Texas A&M University
# 26    209         137                        University of Massachusetts
# 27    217         144                University of South Florida (Tampa)
# 28    220         146                                 University of Utah
# 29    243         157  Virginia Polytechnic Institute and State Unive...
# 30    277         175                           Florida State University
# 31    310         194                    North Carolina State University
# 32    312         195                                  Temple University
# 33    393         230                          University of Connecticut
# 34    400         233                              Iowa State University
# 35    403         234                              University of Georgia
# 36    431         246                              University of Alabama
# 37    440         248              University of South Carolina-Columbia
# 38    478         262                              University of Houston
# 39    507         271                   Florida International University
# 40    558         290                         San Diego State University
# 41    609         304                      University of Central Florida
# 42    638         314                              Texas Tech University
# 43   1015         429            California State University, Long Beach
# 44   1052         438                             Texas State University
#
#           Country  Number_students  Numb_students_per_Staff  \
# 0   United States            41081                     13.7
# 1   United States            41066                      9.4
# 2   United States            42982                      8.3
# 3   United States            45692                     11.1
# 4   United States            44466                      8.9
# 5   United States            33579                     13.0
# 6   United States            49165                     17.2
# 7   United States            44916                     17.9
# 8   United States            39154                     10.0
# 9   United States            35419                      9.4
# 10  United States            39164                     12.0
# 11  United States            36929                     11.7
# 12  United States            54372                     12.5
# 13  United States            46204                     15.3
# 14  United States            61120                     12.4
# 15  United States            44789                     16.5
# 16  United States            40451                     15.7
# 17  United States            33108                     16.6
# 18  United States            32706                     16.5
# 19  United States            39124                     18.4
# 20  United States            33186                     16.3
# 21  United States            66872                     13.6
# 22  United States            46683                     21.1
# 23  United States            44801                     11.2
# 24  United States            46642                     16.8
# 25  United States            60818                     24.8
# 26  United States            61204                     13.0
# 27  United States            33885                     18.9
# 28  United States            30365                     14.2
# 29  United States            32838                     18.3
# 30  United States            38520                     24.1
# 31  United States            30231                     12.5
# 32  United States            35814                     13.0
# 33  United States            32446                     15.2
# 34  United States            32469                     18.8
# 35  United States            35164                     16.3
# 36  United States            35120                     22.5
# 37  United States            32291                     16.2
# 38  United States            44128                     25.7
# 39  United States            34203                     23.8
# 40  United States            30799                     30.5
# 41  United States            56228                     35.3
# 42  United States            33015                     20.6
# 43  United States            30595                     19.7
# 44  United States            31893                     19.1
#
#    International_Students Percentage_Female Percentage_Male  Teaching  \
# 0                     17%               50%             50%      83.0
# 1                     17%               54%             46%      83.1
# 2                     17%               49%             51%      79.4
# 3                     16%               53%             47%      72.2
# 4                     33%               57%             43%      76.8
# 5                     23%               46%             54%      62.6
# 6                     10%               52%             48%      68.2
# 7                     24%               47%             53%      63.2
# 8                     13%                0%              0%      68.8
# 9                      8%               57%             43%      59.7
# 10                    14%               58%             42%      62.4
# 11                    25%               53%             47%      54.7
# 12                    13%               50%             50%      57.5
# 13                    16%               46%             54%      55.2
# 14                    11%               52%             48%      55.2
# 15                    16%               51%             49%      56.6
# 16                    23%               43%             57%      57.5
# 17                    11%               48%             52%      46.9
# 18                    26%               52%             48%      43.3
# 19                    10%               52%             48%      52.6
# 20                    11%               44%             56%      44.8
# 21                    15%               52%             48%      50.8
# 22                    21%               43%             57%      39.3
# 23                    17%               52%             48%      47.8
# 24                    10%               55%             45%      54.0
# 25                     8%               47%             53%      49.3
# 26                    15%               48%             52%      38.5
# 27                    14%                0%              0%      30.5
# 28                     8%               47%             53%      39.0
# 29                    14%               43%             57%      37.5
# 30                     7%               56%             44%      38.0
# 31                    15%               45%             55%      36.7
# 32                     9%               53%             47%      39.3
# 33                     9%               53%             47%      36.5
# 34                    12%               44%             56%      29.5
# 35                     7%               57%             43%      34.9
# 36                     4%               56%             44%      26.9
# 37                     5%               55%             45%      33.2
# 38                     9%               50%             50%      33.6
# 39                     8%               57%             43%      30.4
# 40                     8%               55%             45%      23.7
# 41                     4%               56%             44%      26.5
# 42                     9%               46%             54%      30.8
# 43                     4%               58%             42%      23.1
# 44                     1%               58%             42%      17.4
#
#     Research  Citations  Industry_Income  International_Outlook  Score_Result  \
# 0       90.6       99.2             46.1                   70.4          88.3
# 1       88.6       97.3             51.3                   64.1          86.8
# 2       86.1       94.9             47.7                   59.2          83.8
# 3       82.2       98.6             47.5                   60.4          81.6
# 4       77.5       96.5             38.7                   65.4          81.1
# 5       78.9       97.7             90.3                   63.7          78.8
# 6       76.2       93.2             46.6                   39.1          75.4
# 7       78.0       84.4             47.9                   54.3          73.0
# 8       70.3       85.3             46.3                   47.4          72.0
# 9       63.2       96.9             43.9                   38.0          69.9
# 10      66.9       83.2             51.4                   62.4          69.7
# 11      59.3       93.1             39.7                   66.2          68.1
# 12      56.1       87.3             53.3                   59.5          66.1
# 13      67.1       75.7             52.1                   47.4          64.3
# 14      59.3       82.7             78.2                   40.2          64.1
# 15      57.4       80.0             37.8                   63.3          63.9
# 16      66.4       63.0             64.3                   72.0          63.1
# 17      59.1       89.6             39.2                   41.2          62.8
# 18      46.5       94.9             58.9                   71.9          62.3
# 19      53.7       85.3             52.7                   40.2          61.8
# 20      45.6       93.1             41.7                   47.3          59.6
# 21      49.7       76.7             49.8                   53.5          58.4
# 22      50.7       81.6             38.5                   61.8          57.1
# 23      48.5       73.9             41.1                   51.5          56.0
# 24      53.8       61.9             57.9                   40.0          55.4
# 25      54.8       62.8             45.3                   54.3          55.3
# 26      31.1       87.0             49.9                   61.7          52.9
# 27      34.2       87.3             89.0                   54.7          51.9
# 28      34.7       86.4             48.3                   33.0          51.7
# 29      42.3       70.9             47.5                   54.0          50.4
# 30      40.1       69.2             39.4                   43.5          48.4
# 31      35.3       64.7             43.2                   57.8          46.4
# 32      23.5       79.3             34.4                   37.7          46.3
# 33      29.7       60.6             37.9                   49.0          42.7
# 34      33.0       60.5             49.6                   56.7          42.4
# 35      35.8       55.8             37.2                   46.0          42.3
# 36      22.4       77.4             35.3                   28.9          41.1
# 37      25.5       63.7             36.2                   43.2          40.9
# 38      25.9       58.0             36.8                   42.5          39.4
# 39      22.6       62.3             38.0                   39.7          38.5
# 40      24.4       62.0             35.1                   33.9          36.5
# 41      28.7       49.7             42.6                   32.9          35.0
# 42      20.9       46.5             36.2                   48.4          34.0
# 43      10.1       27.3             35.9                   37.3          21.8
# 44      14.3       27.3             36.4                   30.4          20.9
#
#    Overall_Ranking  US_large_rank
# 0            88.30              1
# 1            86.80              2
# 2            83.80              3
# 3            81.60              4
# 4            81.10              5
# 5            78.80              6
# 6            75.40              7
# 7            72.90              8
# 8            72.00              9
# 9            69.90             10
# 10           69.70             11
# 11           68.10             12
# 12           66.10             13
# 13           64.20             14
# 14           64.10             15
# 15           63.90             16
# 16           63.10             17
# 17           62.70             18
# 18           62.30             19
# 19           61.80             20
# 20           59.60             21
# 21           58.40             22
# 22           57.10             23
# 23           56.00             24
# 24           55.40             25
# 25           55.30             26
# 26       50.1�53.7             27
# 27       50.1�53.7             28
# 28       50.1�53.7             29
# 29       50.1�53.7             30
# 30       46.9�50.0             31
# 31       44.5�46.8             32
# 32       44.5�46.8             33
# 33       42.4�44.4             34
# 34       42.4�44.4             35
# 35       38.8�42.3             36
# 36       38.8�42.3             37
# 37       38.8�42.3             38
# 38       38.8�42.3             39
# 39       35.3�38.7             40
# 40       35.3�38.7             41
# 41       28.3�35.2             42
# 42       28.3�35.2             43
# 43       10.7�22.1             44
# 44       10.7�22.1             45

# %% [markdown]
# ## Viewing the Top Large Schools
#
# After all that work, let's check out the top 10 large universities in the United States:

# %%
# Select the top ten large universities in the United States:
df_US_large.head(10)
# Out:
#    index  Score_Rank                                   University  \
# 0     12          13           University of California, Berkeley
# 1     16          16        University of California, Los Angeles
# 2     20          20             University of Michigan-Ann Arbor
# 3     25          25                     University of Washington
# 4     28          27                          New York University
# 5     30          29          University of California, San Diego
# 6     39          34                University of Texas at Austin
# 7     47          41   University of Illinois at Urbana-Champaign
# 8     50          44              University of Wisconsin-Madison
# 9     53          47  University of North Carolina at Chapel Hill
#
#          Country  Number_students  Numb_students_per_Staff  \
# 0  United States            41081                     13.7
# 1  United States            41066                      9.4
# 2  United States            42982                      8.3
# 3  United States            45692                     11.1
# 4  United States            44466                      8.9
# 5  United States            33579                     13.0
# 6  United States            49165                     17.2
# 7  United States            44916                     17.9
# 8  United States            39154                     10.0
# 9  United States            35419                      9.4
#
#   International_Students Percentage_Female Percentage_Male  Teaching  \
# 0                    17%               50%             50%      83.0
# 1                    17%               54%             46%      83.1
# 2                    17%               49%             51%      79.4
# 3                    16%               53%             47%      72.2
# 4                    33%               57%             43%      76.8
# 5                    23%               46%             54%      62.6
# 6                    10%               52%             48%      68.2
# 7                    24%               47%             53%      63.2
# 8                    13%                0%              0%      68.8
# 9                     8%               57%             43%      59.7
#
#    Research  Citations  Industry_Income  International_Outlook  Score_Result  \
# 0      90.6       99.2             46.1                   70.4          88.3
# 1      88.6       97.3             51.3                   64.1          86.8
# 2      86.1       94.9             47.7                   59.2          83.8
# 3      82.2       98.6             47.5                   60.4          81.6
# 4      77.5       96.5             38.7                   65.4          81.1
# 5      78.9       97.7             90.3                   63.7          78.8
# 6      76.2       93.2             46.6                   39.1          75.4
# 7      78.0       84.4             47.9                   54.3          73.0
# 8      70.3       85.3             46.3                   47.4          72.0
# 9      63.2       96.9             43.9                   38.0          69.9
#
#   Overall_Ranking  US_large_rank
# 0           88.30              1
# 1           86.80              2
# 2           83.80              3
# 3           81.60              4
# 4           81.10              5
# 5           78.80              6
# 6           75.40              7
# 7           72.90              8
# 8           72.00              9
# 9           69.90             10

# %%
### TEST CASE for Puzzle 2.2: Using the index to store a US_large_rank
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert("US_large_rank" in df_US_large)
assert(df_US_large.loc[0][0] == df_US_large.iloc[0][0])
assert(df_US_large.loc[0]["US_large_rank"] == 1)
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉
# /var/folders/ns/z4mk9l_x1_q4v3pm60vk8ns40000gn/T/ipykernel_31080/777173812.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert(df_US_large.loc[0][0] == df_US_large.iloc[0][0])

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 3: Creating Random Subsets
#
# Instead of focusing on just a subset of a DataFrame, researchers often need to look at a random sample of a DataFrame.
#
# Returning to the original dataset of nearly 1,400 universities, create one new DataFrame, `df_random_15` , that gives us a random sample of 15 rows in the dataset.

# %%
df_random_15 = df.sample(15)
df_random_15
# Out:
#       Score_Rank                                       University  \
# 602          302                           Dublin City University
# 477          261         Indian Institute of Technology Kharagpur
# 255          165                Chalmers University of Technology
# 731          347                                Ulster University
# 216          143                   Hebrew University of Jerusalem
# 1108         452                Federal University of Cear� (UFC)
# 271          173                            University of Navarra
# 1389         529                      S�leyman Demirel University
# 1160         465  Lobachevsky State University of Nizhni Novgorod
# 82            67                              Sorbonne University
# 420          241                   University of Nebraska-Lincoln
# 1087         447                 Federal University of S�o Carlos
# 145          108                             University of Exeter
# 388          227                                �rebro University
# 1361         516                        Voronezh State University
#
#                  Country  Number_students  Numb_students_per_Staff  \
# 602              Ireland            12619                     24.0
# 477                India             9167                     12.3
# 255               Sweden             9209                     12.5
# 731       United Kingdom            17817                     17.1
# 216               Israel            16137                     12.0
# 1108              Brazil            34676                     17.2
# 271                Spain            10833                     13.0
# 1389              Turkey            46705                     27.5
# 1160  Russian Federation            18077                      7.9
# 82                France            43076                     13.5
# 420        United States            24610                     17.2
# 1087              Brazil            19134                     14.6
# 145       United Kingdom            21451                     17.6
# 388               Sweden             9735                     18.5
# 1361  Russian Federation            15246                     11.0
#
#      International_Students Percentage_Female Percentage_Male  Teaching  \
# 602                     10%               57%             43%      21.0
# 477                      0%               18%             82%      41.3
# 255                     17%               32%             68%      36.1
# 731                      8%               55%             45%      21.0
# 216                      5%               56%             44%      48.2
# 1108                     1%               46%             54%      22.4
# 271                     22%               53%             47%      30.4
# 1389                     3%               48%             52%      11.2
# 1160                     7%               53%             47%      25.6
# 82                      19%               58%             42%      62.3
# 420                     11%               48%             52%      30.1
# 1087                     2%               49%             51%      26.2
# 145                     28%               54%             46%      33.9
# 388                      6%               61%             39%      17.6
# 1361                    10%               58%             42%      21.1
#
#       Research  Citations  Industry_Income  International_Outlook  \
# 602       25.2       49.7             42.8                   71.8
# 477       38.9       39.0             91.9                   18.8
# 255       42.1       60.0             74.1                   82.9
# 731       18.0       40.9             35.6                   75.7
# 216       45.1       62.3             41.4                   60.3
# 1108      11.8       20.7             38.6                   25.8
# 271       27.9       80.3             85.5                   65.1
# 1389       8.4       11.5             34.5                   17.6
# 1160      11.6       12.4             43.7                   28.6
# 82        50.6       79.9             38.4                   69.2
# 420       28.0       63.2             38.6                   56.7
# 1087      13.4       17.3             41.2                   24.5
# 145       38.9       92.4             37.8                   91.9
# 388       21.1       88.7             36.0                   52.2
# 1361       8.7        4.2             35.3                   25.9
#
#       Score_Result Overall_Ranking
# 602           35.2       28.3�35.2
# 477           39.5       38.8�42.3
# 255           49.5       46.9�50.0
# 731           30.5       28.3�35.2
# 216           52.2       50.1�53.7
# 1108          19.4       10.7�22.1
# 271           48.6       46.9�50.0
# 1389          11.5       10.7�22.1
# 1160          18.1       10.7�22.1
# 82            64.0           64.00
# 420           41.6       38.8�42.3
# 1087          19.9       10.7�22.1
# 145           57.4           57.40
# 388           43.0       42.4�44.4
# 1361          13.0       10.7�22.1

# %%
### TEST CASE for Puzzle 3: Creating random subsets
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert('df_random_15' in vars()), "Make sure to name the dataframe df_random_15."
assert(len(df_random_15) == 15), "It looks like you did not sample exactly 15 rows."
assert(len(df_random_15[df_random_15.Country != "United States"]) > 0), "Make sure to sample from the full dataset stored in `df`"
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and return to https://discovery.cs.illinois.edu/microproject/world-university-rankings/ and complete the section **"Commit and Grade Your Notebook"**.
#
# 3. If you see a 100% grade result on your GitHub Action, you've completed this MicroProject! 🎉
