# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject</div>
# <span style="">MicroProject: Exploring COVID-19 Data from GitHub</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/covid-data-from-github/">https://discovery.cs.illinois.edu/microproject/covid-data-from-github/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Data Source: COVID-19 Case Data from Johns Hopkins University, via GitHub
#
# Since before COVID-19 was detected in the United States, the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University provided daily updates of COVID-19 case data as clean, structured CSV files on GitHub as a free public service to the world.  They continued this free, public service for over three years until March 10, 2023.
#
# You can view the archive of their COVID-19 GitHub repository here: [https://github.com/CSSEGISandData/COVID-19](https://github.com/CSSEGISandData/COVID-19).  Explore their daily reports by navigating into their repository:
#
# - Click **csse_covid_19_data** to navigate into the `csse_covid_19_data` folder,
# - Navigate into `csse_covid_19_daily_reports`,
# - Find the CSV data for **Jan. 3, 2022** *(it'll be near the top, be careful to get the correct year)*
# - Click the **Raw** button to above the file contents to navigate to the raw CSV version of the file (without the GitHub interface)
# - Use the URL of the **raw data as your dataset** for this MicroProject.
#
# Use panda's `read_csv` function to read the dataset you found and create a DataFrame called `df`:

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2022.csv")
df
# Out:
#       FIPS Admin2    Province_State  Country_Region          Last_Update  \
# 0      NaN    NaN               NaN     Afghanistan  2022-01-04 04:22:17
# 1      NaN    NaN               NaN         Albania  2022-01-04 04:22:17
# 2      NaN    NaN               NaN         Algeria  2022-01-04 04:22:17
# 3      NaN    NaN               NaN         Andorra  2022-01-04 04:22:17
# 4      NaN    NaN               NaN          Angola  2022-01-04 04:22:17
# ...    ...    ...               ...             ...                  ...
# 4011   NaN    NaN           Unknown         Ukraine  2022-01-04 04:22:17
# 4012   NaN    NaN               NaN           Nauru  2022-01-04 04:22:17
# 4013   NaN    NaN              Niue     New Zealand  2022-01-04 04:22:17
# 4014   NaN    NaN               NaN          Tuvalu  2022-01-04 04:22:17
# 4015   NaN    NaN  Pitcairn Islands  United Kingdom  2022-01-04 04:22:17
#
#            Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0     33.93911   67.709953     158183    7364        NaN     NaN
# 1     41.15330   20.168300     210885    3220        NaN     NaN
# 2     28.03390    1.659600     219532    6298        NaN     NaN
# 3     42.50630    1.521800      24502     140        NaN     NaN
# 4    -11.20270   17.873900      83764    1775        NaN     NaN
# ...        ...         ...        ...     ...        ...     ...
# 4011       NaN         NaN          0       0        0.0     0.0
# 4012  -0.52280  166.931500          0       0        0.0     0.0
# 4013 -19.05440 -169.867200          0       0        0.0     0.0
# 4014  -7.10950  177.649300          0       0        0.0     0.0
# 4015 -24.37680 -128.324200          0       0        0.0     0.0
#
#                           Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0                          Afghanistan     406.344057             4.655368
# 1                              Albania    7327.993606             1.526899
# 2                              Algeria     500.631194             2.868830
# 3                              Andorra   31711.641752             0.571382
# 4                               Angola     254.863132             2.119049
# ...                                ...            ...                  ...
# 4011                  Unknown, Ukraine       0.000000             0.000000
# 4012                             Nauru       0.000000             0.000000
# 4013                 Niue, New Zealand       0.000000             0.000000
# 4014                            Tuvalu       0.000000             0.000000
# 4015  Pitcairn Islands, United Kingdom       0.000000             0.000000
#
# [4016 rows x 14 columns]

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Data Import
tada = "\N{PARTY POPPER}"

assert("df" in vars())
assert("Country_Region" in df)
assert("People_Hospitalized" not in df), "Make sure you have the global daily reports, not just the US daily reports."
assert("India" in df["Country_Region"].unique())
assert("2022-01-04" in df["Last_Update"].unique()[0]), "Make sure you have the Jan. 3, 2022 CSV file."
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Country-Level Analysis of COVID-19
#
# The CSV file from JHU provides the **total reported cases over all time until the end of the day on Jan. 3, 2022**.  However, the data often breaks countries into individual regions.  For example, let's check out the United States.  Create a DataFrame with all records from the dataset with data about the United States in the variable `df_us`:

# %%
df_us = df[df["Country_Region"] == "US"]
df_us
# Out:
#          FIPS      Admin2 Province_State Country_Region          Last_Update  \
# 673    1001.0     Autauga        Alabama             US  2022-01-04 04:22:17
# 674    1003.0     Baldwin        Alabama             US  2022-01-04 04:22:17
# 675    1005.0     Barbour        Alabama             US  2022-01-04 04:22:17
# 676    1007.0        Bibb        Alabama             US  2022-01-04 04:22:17
# 677    1009.0      Blount        Alabama             US  2022-01-04 04:22:17
# ...       ...         ...            ...            ...                  ...
# 3947  56039.0       Teton        Wyoming             US  2022-01-04 04:22:17
# 3948  56041.0       Uinta        Wyoming             US  2022-01-04 04:22:17
# 3949  90056.0  Unassigned        Wyoming             US  2022-01-04 04:22:17
# 3950  56043.0    Washakie        Wyoming             US  2022-01-04 04:22:17
# 3951  56045.0      Weston        Wyoming             US  2022-01-04 04:22:17
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 673   32.539527  -86.644082      11256     160        NaN     NaN
# 674   30.727750  -87.722071      40549     593        NaN     NaN
# 675   31.868263  -85.387129       3961      81        NaN     NaN
# 676   32.996421  -87.125115       4594      95        NaN     NaN
# 677   33.982109  -86.567906      11368     198        NaN     NaN
# ...         ...         ...        ...     ...        ...     ...
# 3947  43.935225 -110.589080       6273      14        NaN     NaN
# 3948  41.287818 -110.547578       4173      31        NaN     NaN
# 3949        NaN         NaN          0       0        NaN     NaN
# 3950  43.904516 -107.680187       1886      37        NaN     NaN
# 3951  43.839612 -104.567488       1257      14        NaN     NaN
#
#                  Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 673      Autauga, Alabama, US   20147.129893             1.421464
# 674      Baldwin, Alabama, US   18164.347725             1.462428
# 675      Barbour, Alabama, US   16045.531880             2.044938
# 676         Bibb, Alabama, US   20514.423506             2.067915
# 677       Blount, Alabama, US   19658.976931             1.741731
# ...                       ...            ...                  ...
# 3947       Teton, Wyoming, US   26734.572110             0.223179
# 3948       Uinta, Wyoming, US   20631.859982             0.742871
# 3949  Unassigned, Wyoming, US            NaN                  NaN
# 3950    Washakie, Wyoming, US   24163.997438             1.961824
# 3951      Weston, Wyoming, US   18146.383716             1.113763
#
# [3279 rows x 14 columns]

# %% [markdown]
# ### Analysis of COVID-19 in the United States
#
# Create a new DataFrame, `df_us_sorted`, that sorts the DataFrame based on the number of confirmed cases of COVID-19 in the United States, where the **first row contains the location with the highest number of confirmed cases**:

# %%
df_us_sorted = df_us.groupby("Province_State").agg("sum").reset_index()
df_us_sorted.sort_values(by="Confirmed", ascending=False)
df_us_sorted
# Out:
#               Province_State        FIPS  \
# 0                    Alabama    241491.0
# 1                     Alaska    154366.0
# 2             American Samoa        60.0
# 3                    Arizona    230216.0
# 4                   Arkansas    470630.0
# 5                 California    521376.0
# 6                   Colorado    685999.0
# 7                Connecticut    162073.0
# 8                   Delaware    120019.0
# 9           Diamond Princess     88888.0
# 10      District of Columbia     11001.0
# 11                   Florida    898562.0
# 12                   Georgia   2262703.0
# 13            Grand Princess     99999.0
# 14                      Guam        66.0
# 15                    Hawaii    230050.0
# 16                     Idaho    795952.0
# 17                  Illinois   1914438.0
# 18                   Indiana   1754482.0
# 19                      Iowa   1980820.0
# 20                    Kansas   2281065.0
# 21                  Kentucky   2624421.0
# 22                 Louisiana   1582140.0
# 23                     Maine    538302.0
# 24                  Maryland    667103.0
# 25             Massachusetts    390195.0
# 26                  Michigan   2334941.0
# 27                 Minnesota   2446596.0
# 28               Mississippi   2392752.0
# 29                  Missouri   3438566.0
# 30                   Montana   1773166.0
# 31                  Nebraska   2981680.0
# 32                    Nevada    634806.0
# 33             New Hampshire    420133.0
# 34                New Jersey    804475.0
# 35                New Mexico   1246030.0
# 36                  New York   2405916.0
# 37            North Carolina   3800037.0
# 38              North Dakota   2106847.0
# 39  Northern Mariana Islands        69.0
# 40                      Ohio   3529783.0
# 41                  Oklahoma   3256009.0
# 42                    Oregon   1567337.0
# 43              Pennsylvania   2908531.0
# 44               Puerto Rico   5767870.0
# 45                 Recovered         0.0
# 46              Rhode Island    310069.0
# 47            South Carolina   2162161.0
# 48              South Dakota   3130531.0
# 49                 Tennessee   4644119.0
# 50                     Texas  12346564.0
# 51                      Utah    433320.0
# 52                   Vermont    790246.0
# 53            Virgin Islands        78.0
# 54                  Virginia   6908162.0
# 55                Washington   2158574.0
# 56             West Virginia   3063079.0
# 57                 Wisconsin   4055174.0
# 58                   Wyoming   1378585.0
#
#                                                Admin2  \
# 0   AutaugaBaldwinBarbourBibbBlountBullockButlerCa...
# 1   Aleutians EastAleutians WestAnchorageBethelBri...
# 2                                                   0
# 3   ApacheCochiseCoconinoGilaGrahamGreenleeLa PazM...
# 4   ArkansasAshleyBaxterBentonBooneBradleyCalhounC...
# 5   AlamedaAlpineAmadorButteCalaverasColusaContra ...
# 6   AdamsAlamosaArapahoeArchuletaBacaBentBoulderBr...
# 7   FairfieldHartfordLitchfieldMiddlesexNew HavenN...
# 8                      KentNew CastleSussexUnassigned
# 9                                                   0
# 10                               District of Columbia
# 11  AlachuaBakerBayBradfordBrevardBrowardCalhounCh...
# 12  ApplingAtkinsonBaconBakerBaldwinBanksBarrowBar...
# 13                                                  0
# 14                                                  0
# 15         HawaiiHonoluluKauaiMauiOut of HIUnassigned
# 16  AdaAdamsBannockBear LakeBenewahBinghamBlaineBo...
# 17  AdamsAlexanderBondBooneBrownBureauCalhounCarro...
# 18  AdamsAllenBartholomewBentonBlackfordBooneBrown...
# 19  AdairAdamsAllamakeeAppanooseAudubonBentonBlack...
# 20  AllenAndersonAtchisonBarberBartonBourbonBrownB...
# 21  AdairAllenAndersonBallardBarrenBathBellBooneBo...
# 22  AcadiaAllenAscensionAssumptionAvoyellesBeaureg...
# 23  AndroscogginAroostookCumberlandFranklinHancock...
# 24  AlleganyAnne ArundelBaltimoreBaltimore CityCal...
# 25  BarnstableBerkshireBristolDukes and NantucketE...
# 26  AlconaAlgerAlleganAlpenaAntrimArenacBaragaBarr...
# 27  AitkinAnokaBeckerBeltramiBentonBig StoneBlue E...
# 28  AdamsAlcornAmiteAttalaBentonBolivarCalhounCarr...
# 29  AdairAndrewAtchisonAudrainBarryBartonBatesBent...
# 30  BeaverheadBig HornBlaineBroadwaterCarbonCarter...
# 31  AdamsAntelopeArthurBannerBlaineBooneBox ButteB...
# 32  Carson CityChurchillClarkDouglasElkoEsmeraldaE...
# 33  BelknapCarrollCheshireCoosGraftonHillsboroughM...
# 34  AtlanticBergenBurlingtonCamdenCape MayCumberla...
# 35  BernalilloCatronChavesCibolaColfaxCurryDe Baca...
# 36  AlbanyAlleganyBronxBroomeCattaraugusCayugaChau...
# 37  AlamanceAlexanderAlleghanyAnsonAsheAveryBeaufo...
# 38  AdamsBarnesBensonBillingsBottineauBowmanBurkeB...
# 39                                                  0
# 40  AdamsAllenAshlandAshtabulaAthensAuglaizeBelmon...
# 41  AdairAlfalfaAtokaBeaverBeckhamBlaineBryanCaddo...
# 42  BakerBentonClackamasClatsopColumbiaCoosCrookCu...
# 43  AdamsAlleghenyArmstrongBeaverBedfordBerksBlair...
# 44  AdjuntasAguadaAguadillaAguas BuenasAibonitoAna...
# 45                                                  0
# 46   BristolKentNewportProvidenceUnassignedWashington
# 47  AbbevilleAikenAllendaleAndersonBambergBarnwell...
# 48  AuroraBeadleBennettBon HommeBrookingsBrownBrul...
# 49  AndersonBedfordBentonBledsoeBlountBradleyCampb...
# 50  AndersonAndrewsAngelinaAransasArcherArmstrongA...
# 51  Bear RiverCentral UtahDavisSalt LakeSan JuanSo...
# 52  AddisonBenningtonCaledoniaChittendenEssexFrank...
# 53                                                  0
# 54  AccomackAlbemarleAlexandriaAlleghanyAmeliaAmhe...
# 55  AdamsAsotinBentonChelanClallamClarkColumbiaCow...
# 56  BarbourBerkeleyBooneBraxtonBrookeCabellCalhoun...
# 57  AdamsAshlandBarronBayfieldBrownBuffaloBurnettC...
# 58  AlbanyBig HornCampbellCarbonConverseCrookFremo...
#
#                                        Country_Region  \
# 0   USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 1   USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 2                                                  US
# 3                  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS
# 4   USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 5   USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 6   USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 7                                  USUSUSUSUSUSUSUSUS
# 8                                            USUSUSUS
# 9                                                  US
# 10                                                 US
# 11  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 12  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 13                                                 US
# 14                                                 US
# 15                                       USUSUSUSUSUS
# 16  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 17  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 18  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 19  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 20  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 21  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 22  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 23               USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS
# 24  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 25                       USUSUSUSUSUSUSUSUSUSUSUSUSUS
# 26  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 27  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 28  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 29  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 30  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 31  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 32               USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS
# 33                             USUSUSUSUSUSUSUSUSUSUS
# 34       USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS
# 35  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 36  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 37  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 38  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 39                                                 US
# 40  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 41  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 42  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 43  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 44  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 45                                                 US
# 46                                       USUSUSUSUSUS
# 47  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 48  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 49  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 50  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 51                       USUSUSUSUSUSUSUSUSUSUSUSUSUS
# 52                     USUSUSUSUSUSUSUSUSUSUSUSUSUSUS
# 53                                                 US
# 54  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 55  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 56  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 57  USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 58   USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS
#
#                                           Last_Update          Lat  \
# 0   2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2203.246784
# 1   2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1810.439952
# 2                                 2022-01-04 04:22:17   -14.271000
# 3   2022-01-04 04:22:172022-01-04 04:22:172022-01-...   505.138555
# 4   2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2618.391704
# 5   2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2194.949775
# 6   2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2491.870366
# 7   2022-01-04 04:22:172022-01-04 04:22:172022-01-...   332.909441
# 8   2022-01-04 04:22:172022-01-04 04:22:172022-01-...   117.327830
# 9                                 2020-08-04 02:27:56     0.000000
# 10                                2022-01-04 04:22:17    38.904178
# 11  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1939.030577
# 12  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  5216.556611
# 13                                2020-08-04 02:27:56     0.000000
# 14                                2022-01-04 04:22:17    13.444300
# 15  2022-01-04 04:22:172022-01-04 04:22:172022-01-...    83.962590
# 16  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1947.589655
# 17  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  4064.049006
# 18  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3665.036491
# 19  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  4160.961092
# 20  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  4040.964784
# 21  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  4514.657262
# 22  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1989.915353
# 23  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   715.003015
# 24  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   936.358097
# 25  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   548.293200
# 26  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3655.620467
# 27  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3963.025129
# 28  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2689.003578
# 29  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  4460.984726
# 30  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2630.582703
# 31  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3842.926930
# 32  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   667.351945
# 33  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   434.789729
# 34  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   846.015259
# 35  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1140.128846
# 36  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2637.737383
# 37  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3562.420971
# 38  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2511.855857
# 39                                2022-01-04 04:22:17    15.097900
# 40  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3547.338944
# 41  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2733.647411
# 42  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1601.726424
# 43  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2734.811250
# 44  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1422.729273
# 45                                2022-01-04 04:22:17     0.000000
# 46  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   208.275711
# 47  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1562.043718
# 48  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2921.997865
# 49  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3409.084710
# 50  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  8041.803434
# 51  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   520.187201
# 52  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   618.232941
# 53                                2022-01-04 04:22:17    18.335800
# 54  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  4996.297993
# 55  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  1842.117670
# 56  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  2134.783954
# 57  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  3196.450332
# 58  2022-01-04 04:22:172022-01-04 04:22:172022-01-...   990.998367
#
#            Long_  Confirmed  Deaths  Recovered  Active  \
# 0   -5809.578199     913603   16455        0.0     0.0
# 1   -4470.218368     160089     979        0.0     0.0
# 2    -170.132000         11       0        0.0     0.0
# 3   -1671.948482    1404601   24355        0.0     0.0
# 4   -6932.548370     574572    9221        0.0     0.0
# 5   -7002.258461    5707212   76469        0.0     0.0
# 6   -6751.119357    1038681   10921        0.0     0.0
# 7    -581.254637     533866    9210        0.0     0.0
# 8    -226.599712     189382    2286        0.0     0.0
# 9       0.000000         49       0        0.0     0.0
# 10    -77.016560     103487    1218        0.0     0.0
# 11  -5540.949842    4209927   62504        0.0     0.0
# 12 -13288.811358    1839879   31443        0.0     0.0
# 13      0.000000        103       3        0.0     0.0
# 14    144.793700      19689     273        0.0     0.0
# 15   -629.657823     121864    1094        0.0     0.0
# 16  -5036.245496     320802    4169        0.0     0.0
# 17  -9096.189667    2238762   31194        0.0     0.0
# 18  -7932.108297    1278285   19084        0.0     0.0
# 19  -9253.086423     575501    7858        0.0     0.0
# 20 -10298.877911     534219    7049        0.0     0.0
# 21 -10223.986874     879057   12234        0.0     0.0
# 22  -5876.747946     859856   15001        0.0     0.0
# 23  -1112.380298     146736    1531        0.0     0.0
# 24  -1840.211223     761924   11896        0.0     0.0
# 25   -930.501649    1173704   16744        0.0     0.0
# 26  -7070.080729    1775882   29343        0.0     0.0
# 27  -8215.492913    1028986   10704        0.0     0.0
# 28  -7350.949516     561262   10455        0.0     0.0
# 29 -10729.940479    1021433   16237        0.0     0.0
# 30  -6143.222113     198520    2908        0.0     0.0
# 31  -9210.628137     344392    3338        0.0     0.0
# 32  -1998.587890     497084    8427        0.0     0.0
# 33   -715.776567     203749    1973        0.0     0.0
# 34  -1567.071444    1644839   29073        0.0     0.0
# 35  -3494.274545     357480    5866        0.0     0.0
# 36  -4679.399365    3684152   59760        0.0     0.0
# 37  -7950.109874    1732568   19457        0.0     0.0
# 38  -5313.217852     176051    2057        0.0     0.0
# 39    145.673900       3297      17        0.0     0.0
# 40  -7289.515905    2072663   32293        0.0     0.0
# 41  -7488.357767     716851   12503        0.0     0.0
# 42  -4373.169106     430931    5666        0.0     0.0
# 43  -5200.226295    2101019   36799        0.0     0.0
# 44  -5179.588874     303533    3314        0.0     0.0
# 45      0.000000          0       0        0.0     0.0
# 46   -357.320525     231096    3066        0.0     0.0
# 47  -3725.236386     975320   14636        0.0     0.0
# 48  -6554.501988     179983    2494        0.0     0.0
# 49  -8180.328684    1460431   20832        0.0     0.0
# 50 -25057.879425    4795121   75917        0.0     0.0
# 51  -1448.991415     651746    3804        0.0     0.0
# 52  -1017.581330      67226     480        0.0     0.0
# 53    -64.896300      10290      89        0.0     0.0
# 54 -10442.323661    1158764   15615        0.0     0.0
# 55  -4708.049596     882144    9853        0.0     0.0
# 56  -4433.959998     337326    5356        0.0     0.0
# 57  -6465.454559    1132356   11185        0.0     0.0
# 58  -2464.524571     116643    1526        0.0     0.0
#
#                                          Combined_Key  Incident_Rate  \
# 0   Autauga, Alabama, USBaldwin, Alabama, USBarbou...   1.227049e+06
# 1   Aleutians East, Alaska, USAleutians West, Alas...   5.482503e+05
# 2                                  American Samoa, US   1.797236e+01
# 3   Apache, Arizona, USCochise, Arizona, USCoconin...   2.969747e+05
# 4   Arkansas, Arkansas, USAshley, Arkansas, USBaxt...   1.421224e+06
# 5   Alameda, California, USAlpine, California, USA...   7.691524e+05
# 6   Adams, Colorado, USAlamosa, Colorado, USArapah...   1.081128e+06
# 7   Fairfield, Connecticut, USHartford, Connecticu...   1.113267e+05
# 8   Kent, Delaware, USNew Castle, Delaware, USSuss...   5.832301e+04
# 9                                Diamond Princess, US   0.000000e+00
# 10     District of Columbia, District of Columbia ,US   1.466343e+04
# 11  Alachua, Florida, USBaker, Florida, USBay, Flo...   1.233186e+06
# 12  Appling, Georgia, USAtkinson, Georgia, USBacon...   2.737842e+06
# 13                                 Grand Princess, US   0.000000e+00
# 14                                           Guam, US   1.198875e+04
# 15  Hawaii, Hawaii, USHonolulu, Hawaii, USKauai, H...   2.969801e+04
# 16  Ada, Idaho, USAdams, Idaho, USBannock, Idaho, ...   6.964333e+05
# 17  Adams, Illinois, USAlexander, Illinois, USBond...   2.035190e+06
# 18  Adams, Indiana, USAllen, Indiana, USBartholome...   1.783648e+06
# 19  Adair, Iowa, USAdams, Iowa, USAllamakee, Iowa,...   1.819158e+06
# 20  Allen, Kansas, USAnderson, Kansas, USAtchison,...   2.079506e+06
# 21  Adair, Kentucky, USAllen, Kentucky, USAnderson...   2.425947e+06
# 22  Acadia, Louisiana, USAllen, Louisiana, USAscen...   1.209532e+06
# 23  Androscoggin, Maine, USAroostook, Maine, USCum...   1.709185e+05
# 24  Allegany, Maryland, USAnne Arundel, Maryland, ...   3.037821e+05
# 25  Barnstable, Massachusetts, USBerkshire, Massac...   1.925458e+05
# 26  Alcona, Michigan, USAlger, Michigan, USAllegan...   1.385396e+06
# 27  Aitkin, Minnesota, USAnoka, Minnesota, USBecke...   1.679798e+06
# 28  Adams, Mississippi, USAlcorn, Mississippi, USA...   1.573186e+06
# 29  Adair, Missouri, USAndrew, Missouri, USAtchiso...   1.949194e+06
# 30  Beaverhead, Montana, USBig Horn, Montana, USBl...   9.675000e+05
# 31  Adams, Nebraska, USAntelope, Nebraska, USArthu...   1.447039e+06
# 32  Carson City, Nevada, USChurchill, Nevada, USCl...   2.309240e+05
# 33  Belknap, New Hampshire, USCarroll, New Hampshi...   1.413203e+05
# 34  Atlantic, New Jersey, USBergen, New Jersey, US...   3.782416e+05
# 35  Bernalillo, New Mexico, USCatron, New Mexico, ...   5.391196e+05
# 36  Albany, New York, USAllegany, New York, USBron...   9.810061e+05
# 37  Alamance, North Carolina, USAlexander, North C...   1.670706e+06
# 38  Adams, North Dakota, USBarnes, North Dakota, U...   1.101680e+06
# 39                       Northern Mariana Islands, US   5.978892e+03
# 40  Adams, Ohio, USAllen, Ohio, USAshland, Ohio, U...   1.583497e+06
# 41  Adair, Oklahoma, USAlfalfa, Oklahoma, USAtoka,...   1.388335e+06
# 42  Baker, Oregon, USBenton, Oregon, USClackamas, ...   4.357884e+05
# 43  Adams, Pennsylvania, USAllegheny, Pennsylvania...   1.155543e+06
# 44  Adjuntas, Puerto Rico, USAguada, Puerto Rico, ...   6.281112e+05
# 45                                      Recovered, US   0.000000e+00
# 46  Bristol, Rhode Island, USKent, Rhode Island, U...   8.434632e+04
# 47  Abbeville, South Carolina, USAiken, South Caro...   8.393307e+05
# 48  Aurora, South Dakota, USBeadle, South Dakota, ...   1.257732e+06
# 49  Anderson, Tennessee, USBedford, Tennessee, USB...   2.057456e+06
# 50  Anderson, Texas, USAndrews, Texas, USAngelina,...   4.258929e+06
# 51  Bear River, Utah, USCentral Utah, Utah, USDavi...   2.557148e+05
# 52  Addison, Vermont, USBennington, Vermont, USCal...   1.514997e+05
# 53                                 Virgin Islands, US   9.592796e+03
# 54  Accomack, Virginia, USAlbemarle, Virginia, USA...   1.957991e+06
# 55  Adams, Washington, USAsotin, Washington, USBen...   4.757024e+05
# 56  Barbour, West Virginia, USBerkeley, West Virgi...   1.049325e+06
# 57  Adams, Wisconsin, USAshland, Wisconsin, USBarr...   1.408735e+06
# 58  Albany, Wyoming, USBig Horn, Wyoming, USCampbe...   4.538095e+05
#
#     Case_Fatality_Ratio
# 0            146.138272
# 1             15.036896
# 2              0.000000
# 3             33.429040
# 4            148.728195
# 5             65.787011
# 6             87.504955
# 7             13.379777
# 8              3.919849
# 9              0.000000
# 10             1.176959
# 11           933.978010
# 12           396.749662
# 13             2.912621
# 14             1.386561
# 15             3.562066
# 16            69.303317
# 17          1333.540333
# 18           145.622491
# 19           174.924548
# 20           174.567767
# 21           198.874337
# 22           126.984342
# 23            16.745518
# 24            79.464270
# 25            24.321521
# 26           158.272292
# 27           120.746807
# 28           176.892412
# 29           221.511762
# 30           113.878967
# 31           120.840847
# 32            32.310316
# 33            10.194662
# 34            35.988351
# 35            70.510945
# 36            78.397932
# 37           137.425362
# 38            84.089865
# 39             0.515620
# 40           147.027402
# 41           146.698482
# 42            55.095114
# 43           131.967026
# 44            37.620615
# 45             0.000000
# 46             6.727416
# 47            85.448066
# 48           131.135992
# 49           167.780376
# 50           620.892708
# 51             9.221690
# 52             8.947455
# 53             0.864917
# 54           233.181010
# 55            51.607845
# 56            89.333076
# 57            83.740727
# 58            33.281553

# %% [markdown]
# ### Create a DataFrame for Country Level Analysis
#
# Create a new DataFrame, `df_countries`, that aggregates the data within each country together to get a DataFrame that contains one row for each country:

# %%
df_countries = df.groupby("Country_Region").agg("sum").reset_index()
df_countries
# Out:
#            Country_Region  FIPS Admin2 Province_State          Last_Update  \
# 0             Afghanistan   0.0      0              0  2022-01-04 04:22:17
# 1                 Albania   0.0      0              0  2022-01-04 04:22:17
# 2                 Algeria   0.0      0              0  2022-01-04 04:22:17
# 3                 Andorra   0.0      0              0  2022-01-04 04:22:17
# 4                  Angola   0.0      0              0  2022-01-04 04:22:17
# ..                    ...   ...    ...            ...                  ...
# 196    West Bank and Gaza   0.0      0              0  2022-01-04 04:22:17
# 197  Winter Olympics 2022   0.0      0              0  2022-01-04 04:22:17
# 198                 Yemen   0.0      0              0  2022-01-04 04:22:17
# 199                Zambia   0.0      0              0  2022-01-04 04:22:17
# 200              Zimbabwe   0.0      0              0  2022-01-04 04:22:17
#
#            Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0    33.939110   67.709953     158183    7364        0.0     0.0
# 1    41.153300   20.168300     210885    3220        0.0     0.0
# 2    28.033900    1.659600     219532    6298        0.0     0.0
# 3    42.506300    1.521800      24502     140        0.0     0.0
# 4   -11.202700   17.873900      83764    1775        0.0     0.0
# ..         ...         ...        ...     ...        ...     ...
# 196  31.952200   35.233200     469748    4919        0.0     0.0
# 197  39.904200  116.407400          0       0        0.0     0.0
# 198  15.552727   48.516388      10138    1984        0.0     0.0
# 199 -13.133897   27.849332     261221    3753        0.0     0.0
# 200 -19.015438   29.154857     216087    5047        0.0     0.0
#
#              Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0             Afghanistan     406.344057             4.655368
# 1                 Albania    7327.993606             1.526899
# 2                 Algeria     500.631194             2.868830
# 3                 Andorra   31711.641752             0.571382
# 4                  Angola     254.863132             2.119049
# ..                    ...            ...                  ...
# 196    West Bank and Gaza    9208.188472             1.047157
# 197  Winter Olympics 2022       0.000000             0.000000
# 198                 Yemen      33.990515            19.569935
# 199                Zambia    1420.918327             1.436715
# 200              Zimbabwe    1453.865716             2.335633
#
# [201 rows x 14 columns]

# %% [markdown]
# ### Performing Country-Level Analysis

# %% [markdown]
# Create a DataFrame called `df_most_cases` that contains the country which has had the most confirmed cases of COVID-19:

# %%
df_most_cases = df_countries["Confirmed"].nlargest().idxmax()
df_most_cases = df.loc[[df_most_cases]]
df_most_cases
# Out:
#      FIPS Admin2 Province_State Country_Region          Last_Update      Lat  \
# 186   NaN    NaN            NaN         Cyprus  2022-01-04 04:22:17  35.1264
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 186  33.4299     177721     641        NaN     NaN       Cyprus
#
#      Incident_Rate  Case_Fatality_Ratio
# 186    14719.78969             0.360678

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Data Analysis
tada = "\N{PARTY POPPER}"

assert("df_us" in vars())
assert("Province_State" in df_us)

assert("df_us_sorted" in vars())
assert(df_us_sorted.iloc[:,-7].values[2] <= df_us_sorted.iloc[:,-7].values[1])
assert(df_us_sorted.iloc[:,-7].values[10] <= df_us_sorted.iloc[:,-7].values[9])
assert(df_us_sorted["Confirmed"].values[0]) == max(df_us["Confirmed"])

assert("df_countries" in vars())
assert(df_countries["Confirmed"].sum() == df["Confirmed"].cumsum().values[len(df) - 1])

assert("df_most_cases" in vars())
assert(len(df_most_cases) == 1)
assert(len(df_most_cases.iloc[0]["Country_Region"]) == 2)

print(f"{tada} All Tests Passed! {tada}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 9
#       7 assert("df_us_sorted" in vars())
#       8 assert(df_us_sorted.iloc[:,-7].values[2] <= df_us_sorted.iloc[:,-7].values[1])
# ----> 9 assert(df_us_sorted.iloc[:,-7].values[10] <= df_us_sorted.iloc[:,-7].values[9])
#      10 assert(df_us_sorted["Confirmed"].values[0]) == max(df_us["Confirmed"])
#      12 assert("df_countries" in vars())
#
# AssertionError:

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Checking for the Pareto principle
#
# The Pareto principle states that *"for many outcomes, roughly 80% of consequences come from 20% of causes (the "vital few")"* ([See more on Wikipedia: Pareto principle](https://en.wikipedia.org/wiki/Pareto_principle)).  This is also known as the "80-20 rule" and appears often in Data Science.
#
# In terms of COVID-19 cases, the application of the Pareto principle would be that **80% of confirmed cases comes from just 20% of countries**.  Is this true?
#
# To test this, we need to find total number of cases across all countries.  Compute the total number of confirmed cases in the variable `confirmed_total` (this should be a number, not a DataFrame):

# %%
confirmed_total = df["Confirmed"].agg("sum")
confirmed_total
# Out:
# 293190148

# %% [markdown]
# Using a bit of math, 80% of the total number of confirmed cases would be:

# %%
confirmed_80pct = confirmed_total * 0.8
confirmed_80pct
# Out:
# 234552118.4

# %% [markdown]
# ### Finding the Cumulative Sum of Cases
#
# DataFrames provide the function "cumulative sum" function, or `df.cumsum(...)`, that allows us to calculate the sum of every row up until and including the current row.
#
# Read the DISCOVERY guide "What is the Cumulative Sum of a pandas DataFrame?" to find out more on using the cumulative sum function:
# - [Guide: "What is the Cumulative Sum of a pandas DataFrame?"](https://discovery.cs.illinois.edu/guides/DataFrame-Fundamentals/Cumulative-Sum-in-pandas/)
#
# Before finding the cumulative sum, we need to have a sorted DataFrame of all countries in descending order.  Use `df_countries` to create a DataFrame sorted by confirmed cases in the variable `df_countries_sorted`:

# %%
df_countries_sorted = df_countries.sort_values(by="Confirmed", ascending=False)
df_countries_sorted
# Out:
#            Country_Region         FIPS  \
# 186                    US  105902623.0
# 80                  India          0.0
# 24                 Brazil          0.0
# 190        United Kingdom          0.0
# 63                 France          0.0
# ..                    ...          ...
# 181                 Tonga          0.0
# 93           Korea, North          0.0
# 126                 Nauru          0.0
# 197  Winter Olympics 2022          0.0
# 185                Tuvalu          0.0
#
#                                                 Admin2  \
# 186  AutaugaBaldwinBarbourBibbBlountBullockButlerCa...
# 80                                                   0
# 24                                                   0
# 190                                                  0
# 63                                                   0
# ..                                                 ...
# 181                                                  0
# 93                                                   0
# 126                                                  0
# 197                                                  0
# 185                                                  0
#
#                                         Province_State  \
# 186  AlabamaAlabamaAlabamaAlabamaAlabamaAlabamaAlab...
# 80   Andaman and Nicobar IslandsAndhra PradeshAruna...
# 24   AcreAlagoasAmapaAmazonasBahiaCearaDistrito Fed...
# 190  AnguillaBermudaBritish Virgin IslandsCayman Is...
# 63   French GuianaFrench PolynesiaGuadeloupeMartini...
# ..                                                 ...
# 181                                                  0
# 93                                                   0
# 126                                                  0
# 197                                                  0
# 185                                                  0
#
#                                            Last_Update            Lat  \
# 186  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  121693.134039
# 80   2022-01-04 04:22:172022-01-04 04:22:172022-01-...     831.177882
# 24   2022-01-04 04:22:172022-01-04 04:22:172022-01-...    -342.077100
# 190  2022-01-04 04:22:172022-01-04 04:22:172022-01-...     496.754894
# 63   2022-01-04 04:22:172022-01-04 04:22:172022-01-...      77.169695
# ..                                                 ...            ...
# 181                                2022-01-04 04:22:17     -21.179000
# 93                                 2022-01-04 04:22:17      40.339900
# 126                                2022-01-04 04:22:17      -0.522800
# 197                                2022-01-04 04:22:17      39.904200
# 185                                2022-01-04 04:22:17      -7.109500
#
#              Long_  Confirmed  Deaths  Recovered  Active  \
# 186 -293352.619164   56438999  828234        0.0     0.0
# 80     2945.020567   34960261  482017        0.0     0.0
# 24    -1308.973300   22309081  619473        0.0     0.0
# 190    -642.546956   13498751  178396        0.0     0.0
# 63     -416.763414   10422830  125200        0.0     0.0
# ..             ...        ...     ...        ...     ...
# 181    -175.198200          1       0        0.0     0.0
# 93      127.510100          0       0        0.0     0.0
# 126     166.931500          0       0        0.0     0.0
# 197     116.407400          0       0        0.0     0.0
# 185     177.649300          0       0        0.0     0.0
#
#                                           Combined_Key  Incident_Rate  \
# 186  Autauga, Alabama, USBaldwin, Alabama, USBarbou...   5.576002e+07
# 80   Andaman and Nicobar Islands, IndiaAndhra Prade...   1.537603e+05
# 24   Acre, BrazilAlagoas, BrazilAmapa, BrazilAmazon...   3.272539e+05
# 190  Anguilla, United KingdomBermuda, United Kingdo...   1.993084e+05
# 63   French Guiana, FranceFrench Polynesia, FranceG...   1.306596e+05
# ..                                                 ...            ...
# 181                                              Tonga   9.461006e-01
# 93                                        Korea, North   0.000000e+00
# 126                                              Nauru   0.000000e+00
# 197                               Winter Olympics 2022   0.000000e+00
# 185                                             Tuvalu   0.000000e+00
#
#      Case_Fatality_Ratio
# 186          7600.185927
# 80             46.956740
# 24             66.658983
# 190            11.388305
# 63             13.176218
# ..                   ...
# 181             0.000000
# 93              0.000000
# 126             0.000000
# 197             0.000000
# 185             0.000000
#
# [201 rows x 14 columns]

# %% [markdown]
# Using `df_countries_sorted`, create a new column called `Cumulative Confirmed` that contains the cumulative sum of the Confirmed cases:

# %%
df_countries_sorted["Cumulative Confirmed"] = df_countries_sorted["Confirmed"].agg("sum")
df_countries_sorted
# Out:
#            Country_Region         FIPS  \
# 186                    US  105902623.0
# 80                  India          0.0
# 24                 Brazil          0.0
# 190        United Kingdom          0.0
# 63                 France          0.0
# ..                    ...          ...
# 181                 Tonga          0.0
# 93           Korea, North          0.0
# 126                 Nauru          0.0
# 197  Winter Olympics 2022          0.0
# 185                Tuvalu          0.0
#
#                                                 Admin2  \
# 186  AutaugaBaldwinBarbourBibbBlountBullockButlerCa...
# 80                                                   0
# 24                                                   0
# 190                                                  0
# 63                                                   0
# ..                                                 ...
# 181                                                  0
# 93                                                   0
# 126                                                  0
# 197                                                  0
# 185                                                  0
#
#                                         Province_State  \
# 186  AlabamaAlabamaAlabamaAlabamaAlabamaAlabamaAlab...
# 80   Andaman and Nicobar IslandsAndhra PradeshAruna...
# 24   AcreAlagoasAmapaAmazonasBahiaCearaDistrito Fed...
# 190  AnguillaBermudaBritish Virgin IslandsCayman Is...
# 63   French GuianaFrench PolynesiaGuadeloupeMartini...
# ..                                                 ...
# 181                                                  0
# 93                                                   0
# 126                                                  0
# 197                                                  0
# 185                                                  0
#
#                                            Last_Update            Lat  \
# 186  2022-01-04 04:22:172022-01-04 04:22:172022-01-...  121693.134039
# 80   2022-01-04 04:22:172022-01-04 04:22:172022-01-...     831.177882
# 24   2022-01-04 04:22:172022-01-04 04:22:172022-01-...    -342.077100
# 190  2022-01-04 04:22:172022-01-04 04:22:172022-01-...     496.754894
# 63   2022-01-04 04:22:172022-01-04 04:22:172022-01-...      77.169695
# ..                                                 ...            ...
# 181                                2022-01-04 04:22:17     -21.179000
# 93                                 2022-01-04 04:22:17      40.339900
# 126                                2022-01-04 04:22:17      -0.522800
# 197                                2022-01-04 04:22:17      39.904200
# 185                                2022-01-04 04:22:17      -7.109500
#
#              Long_  Confirmed  Deaths  Recovered  Active  \
# 186 -293352.619164   56438999  828234        0.0     0.0
# 80     2945.020567   34960261  482017        0.0     0.0
# 24    -1308.973300   22309081  619473        0.0     0.0
# 190    -642.546956   13498751  178396        0.0     0.0
# 63     -416.763414   10422830  125200        0.0     0.0
# ..             ...        ...     ...        ...     ...
# 181    -175.198200          1       0        0.0     0.0
# 93      127.510100          0       0        0.0     0.0
# 126     166.931500          0       0        0.0     0.0
# 197     116.407400          0       0        0.0     0.0
# 185     177.649300          0       0        0.0     0.0
#
#                                           Combined_Key  Incident_Rate  \
# 186  Autauga, Alabama, USBaldwin, Alabama, USBarbou...   5.576002e+07
# 80   Andaman and Nicobar Islands, IndiaAndhra Prade...   1.537603e+05
# 24   Acre, BrazilAlagoas, BrazilAmapa, BrazilAmazon...   3.272539e+05
# 190  Anguilla, United KingdomBermuda, United Kingdo...   1.993084e+05
# 63   French Guiana, FranceFrench Polynesia, FranceG...   1.306596e+05
# ..                                                 ...            ...
# 181                                              Tonga   9.461006e-01
# 93                                        Korea, North   0.000000e+00
# 126                                              Nauru   0.000000e+00
# 197                               Winter Olympics 2022   0.000000e+00
# 185                                             Tuvalu   0.000000e+00
#
#      Case_Fatality_Ratio  Cumulative Confirmed
# 186          7600.185927             293190148
# 80             46.956740             293190148
# 24             66.658983             293190148
# 190            11.388305             293190148
# 63             13.176218             293190148
# ..                   ...                   ...
# 181             0.000000             293190148
# 93              0.000000             293190148
# 126             0.000000             293190148
# 197             0.000000             293190148
# 185             0.000000             293190148
#
# [201 rows x 15 columns]

# %% [markdown]
# Finally, create a DataFrame called `df_80pct` with all the countries up to the country that, cumulatively, account for 80% of the global cases (remember, that's the cases you stored in `confirmed_80pct`):

# %%
df_80pct = ...
df_80pct

# %% [markdown]
# ### Does the Pareto Principle show up?
#
# Currently:
# - `df_countries` contains EVERY country in the world with COVID-19 data, and
# - `df_80pct` contains countries that make up 80% of the cases.
#
# If the Pareto principle applies to the confirmed cases of COVID-19, then we expect that `df_80pct` holds only approximately 20% of all the countries.  Let's see:

# %%
pct_cases = 100 * sum(df_80pct["Confirmed"]) / sum(df_countries["Confirmed"])
pct_cases = round(pct_cases, 2)

pct_countries = 100 * len(df_80pct) / len(df_countries)
pct_countries = round(pct_countries, 2)

print(f"Result: {pct_cases}% of the COVID-19 cases comes from {pct_countries}% of the countries in the dataset.")

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Pareto Principle
tada = "\N{PARTY POPPER}"

assert("confirmed_total" in vars())
assert("confirmed_80pct" in vars())
assert(confirmed_total > 2.9e8)
                         
assert("df_countries_sorted" in vars())
assert("Cumulative Confirmed" in df_countries_sorted)
assert(max(df_countries_sorted["Cumulative Confirmed"]) == sum(df_countries_sorted["Confirmed"]))
assert(min(df_countries_sorted["Cumulative Confirmed"]) == df_countries_sorted.iloc[0]["Confirmed"])

assert("df_80pct" in vars())
assert("US" in df_80pct["Country_Region"].unique())
assert("India" in df_80pct["Country_Region"].unique())
assert("Tonga" not in df_80pct["Country_Region"].unique())

assert(sum(df_80pct["Confirmed"]) / sum(df_countries["Confirmed"]) > 0.7)
assert(sum(df_80pct["Confirmed"]) / sum(df_countries["Confirmed"]) < 0.9)

assert(len(df_80pct["Confirmed"]) / len(df_countries["Confirmed"]) > 0.1)
assert(len(df_80pct["Confirmed"]) / len(df_countries["Confirmed"]) < 0.2)

print(f"{tada} All Tests Passed! {tada}")

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and return to https://discovery.cs.illinois.edu/microproject/covid-data-from-github/ and complete the section **"Commit and Grade Your Notebook"**.
#
# 3. If you see a 100% grade result on your GitHub Action, you've completed this MicroProject! 🎉
