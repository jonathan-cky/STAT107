# %% [markdown]
# # Welcome to Lab: Favorites!
#
# In this lab, you will explore several favorites of DISCOVERY, including the favorite things of your TA, Karle, and Wade!  This will **help you prepare for the mosaic project that was introduced in lecture on Wednesday**.
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab TA, your CAs, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Alex"
ca1_name = "Annie"
ca2_name = "Eliana"
ca3_name = "Victoria"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!
#
# Question of the Day (QOTD) to Ask Your Group: "What is your favorite influencer?"
partner1_name = ""
partner1_netid = ""
partner1_favinfluencer = ""

partner2_name = ""
partner2_netid = ""
partner2_favinfluencer = ""

partner3_name = ""
partner3_netid = ""
partner3_favinfluencer= ""

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Karle's Game Day!
#
# One of Karle's favorite events is tailgating before Illini football games! The best part of tailgating is obviously the food and drinks 😉. Because Karle is an extrovert, she invites **many** people to her parties. For the upcoming games this fall, she needs to mix "mocktails" in gallons for all of her guests.  In this part of the lab, you will write a simulation to help simulate the possible drinks available at Karle's party.
#
# A "mocktail" has three ingredients:
# - A `mixer`, one of: `"cranberry juice"`, `"lime juice"`, `"lemonade"`, `"kool-aid"`, or `"red bull"` (gross!)
# - A `fruit`, one of: `"watermelon"`, `"pineapple"`, `"lime"`, `"lemon"`, or `"cherry"` (yum!)
# - A `core`, one of: `"sparkling water"`, `"sprite"`, and **add three other things** you should pick with your group to make five `"core"` component options!
#
# Create a DataFrame called `df` containing **10,000** simulations of possible "mocktail" combinations:

# %%
# Write your simulation:
import pandas as pd
import random
lst = []
for i in range(10000):
    m = random.choice(["cranberry juice", "lime juice", "lemonade", "kool-aid", "red bull"])
    f = random.choice(["watermelon", "pineapple", "lime", "lemon", "cherry"])
    c = random.choice(["sparkling water", "sprite", "coke", "mountain dew", "tea"])
    d = {"mixer": m, "fruit": f, "core": c}
    lst.append(d)

# %%
df = pd.DataFrame(lst)
df.rename(columns={0: "mixer", 1: "friut", 1: "core"})
df
# Out:
#                 mixer       fruit             core
# 0            lemonade       lemon           sprite
# 1          lime juice       lemon              tea
# 2          lime juice        lime              tea
# 3     cranberry juice      cherry             coke
# 4          lime juice       lemon           sprite
# ...               ...         ...              ...
# 9995       lime juice   pineapple           sprite
# 9996         red bull   pineapple     mountain dew
# 9997         red bull  watermelon             coke
# 9998         lemonade       lemon  sparkling water
# 9999         red bull   pineapple             coke
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: Karle's Game Day ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
mixers = ["cranberry juice", "lime juice", "lemonade", "kool-aid", "red bull"]
fruits = ["watermelon", "pineapple", "lime", "lemon", "cherry"]
cores = ["sparkling water", "sprite"]
assert( 'df' in vars() ), "Your simulation did not populate a DataFrame variable named `df`."
assert( len(df) == 10000 ), "The length of your `df` is not 10000, check the value in your for-loop declaration."
assert( len(df.columns.to_list()) == 3 ), "Your DataFrame should contain 3 columns!"
assert( 'mixer' in df ), "Your DataFrame is missing a `mixer` column."
assert( 'fruit' in df ), "Your DataFrame is missing a `fruit` column."
assert( 'core' in df ), "Your DataFrame is missing a `core` column."
for m in mixers:
    assert ( m in list(df['mixer']) ), f"Your DataFrame is missing the mixer {m}."
for f in fruits:
    assert ( f in list(df['fruit']) ), f"Your DataFrame is missing the fruit {f}."
for c in cores:
    assert ( c in list(df['core']) ), f"Your DataFrame is missing the core {c}."

assert( len(set(df['core'])) == 5 ), "Your DataFrame does not return five unique core components."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Estimated Probability of Red Bull!
#
# Many people feel the combination of energy drinks with other drinks is gross! Calculate the estimated probability that a randomly created drink has **red bull and sprite** or **red bull and sparkling water** in the variable `P_redBullCombo`. Use your simulation data to do this!

# %%
# P_redBullCombo = (1 / 5)**2 + (1 / 5)**2
P_redBullCombo = len(df[(df["mixer"] == "red bull") & (df["core"] == "sprite")]) + len(df[(df["mixer"] == "red bull") & (df["core"] == "sparkling water")])
P_redBullCombo = P_redBullCombo / len(df)
P_redBullCombo
# Out:
# 0.0794

# %% [markdown]
# ## Estimated Probability of a True Mocktail
#
# Karle is incredibly suspicious of the extra ingredients you picked for her, so we consider a "true mocktail" to be a drink made with a core of `"sparkling water"` or `"sprite"` only.  Calculate the estimated probability that a randomly created drink is a "true mocktail" the variable `P_trueMocktail`:

# %%
# P_trueMocktail = 2/5
P_trueMocktail = df[(df["core"] == "sparkling water") | (df["core"] == "sprite")]
P_trueMocktail = len(P_trueMocktail) / len(df)
P_trueMocktail
# Out:
# 0.3999

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: Mocktail Probabilities ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 0.07 <= P_redBullCombo and 0.095 >= P_redBullCombo ), "You've calculated `P_redBullCombo` incorrectly."
assert( 0.38 <= P_trueMocktail and 0.42 >= P_trueMocktail ), "You've calculated `P_trueMocktail` incorrectly."
'''
NOTE: 
These boundary values were obtained by running 10,000 correct simulations and finding the max, min probability of ALL those runs. 
There is still a chance, albeit *extremely* low, that a student fails this test case with correct code. 
If the value is suspiciously close, try running all cells again. 
'''

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Using Simulations for Estimated Probabilities
#
# **Q1: Why do you think we can use this simulation to estimate the probability of a drink with Red Bull, a "true mocktail", or any other feature we would like to look into?**

# %% [markdown]
# *(✏️ We have enough data to estimate the probability, random sampling, and independent, so we can make the asumption based off the central limit theorem. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Wade's Game Night
#
# While extroverts love their parties, Wade would rather be playing his favorite game with his partner and a small group of friends at home!  One of his favorite games is a table-top game called Dominion.
#
# The only thing you need to know is that your starting hand in Dominion is **five cards** drawn from a starting deck of ten cards.  The deck of ten cards is made up of the following cards:
#
# - There are exactly 7 "coppers" in the starting deck
# - There are exactly 3 "estates" in the starting deck
#
# Here's the whole starting deck from which you'll randomly choose five cards:
#
# ---
#
# ![starting-deck.png](./notebook-images/starting-deck.png)
#
# ---

# %% [markdown]
# To help you out, we have provided a function that returns the number of coppers in a random starting hand -- `coppersInStartingHand`:

# %%
import random

def coppersInStartingHand():
  # This code sample five cards from a set of seven "coppers" and three "estates".
  #   Ex: Might be ["copper", "copper", "copper", "estate", "estate"]  OR
  #       might be ["copper", "copper", "copper", "copper", "copper"]  OR
  #       any other combination of five cards.
  cards = random.sample( (["copper"] * 7) + (["estate"] * 3) , 5 )

  # This code counts the number of "copper" cards selected:
  count = 0
  for card in cards:
    if card == "copper":
      count += 1
  
  return count

coppersInStartingHand()
# Out:
# 5

# %% [markdown]
# Using the `coppersInStartingHand` function, create a DataFrame of 10,000 starting hands of five cards that draws from the ten cards **without replacement**.  In your DataFrame, make sure you have at least the following two columns:
# - `coppers`, the total number of coppers in your starting hand
# - `estates`, the total number of estates in your starting hand
#
# To solve this, think about the relationship between the number of coppers and the number of estates.  For example, if you have 4 coppers, how many estates must you have?
#
# Make sure to call your DataFrame `df_startingHands`.

# %%
# Create your simulation and `df_startingHands`:
lst = []
for i in range (10000):
    c = coppersInStartingHand()
    e = 5 - c
    d = {"coppers" : c, "estates": e}
    lst.append(d)
lst
# Out:
# [{'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 2, 'estates': 3},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 5, 'estates': 0},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 4, 'estates': 1},
#  {'coppers': 3, 'estates': 2},
#  {'coppers': 3, 'estates': 2},
#  ...]

# %%
df_startingHands = pd.DataFrame(lst)
df_startingHands
# Out:
#       coppers  estates
# 0           5        0
# 1           4        1
# 2           4        1
# 3           3        2
# 4           3        2
# ...       ...      ...
# 9995        4        1
# 9996        3        2
# 9997        3        2
# 9998        2        3
# 9999        3        2
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: Wade's Game Night ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
copper_counts = [2, 3, 4, 5]
estate_counts = [0, 1, 2, 3] 
assert( 'df_startingHands' in vars() ), "Your simulation did not populate a DataFrame variable named `df_startingHands`."
assert( len(df_startingHands) == 10000 ), "The length of your DataFrame is not 10000, check the value in your for-loop declaration."
assert( len(df_startingHands.columns.to_list()) == 2 ), "Your `df_startingHands` should contain 2 columns!"
assert( 'coppers' in df_startingHands ), "Your DataFrame is missing a `coppers` column."
assert( 'estates' in df_startingHands ), "Your DataFrame is missing an `estates` column."
for i in copper_counts:
    assert ( i in list(df_startingHands['coppers']) ), f"Your DataFrame is missing instances in which you have {i} coppers in your starting hand. Check your starting hand calculations or your dictionary variables."
for i in estate_counts:
    assert ( i in list(df_startingHands['estates']) ), f"Your DataFrame is missing instances in which you have {i} estates in your starting hand. Check your starting hand calculations or your dictionary variables."

assert ( set(df_startingHands['coppers'] + df_startingHands['estates']) == {5}), "A starting hand should always have 5 cards. Your simulation produced an instance where this is not true."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## A Lucky Start

# %% [markdown]
# One of the luckiest starting hands is to have **five coppers**.  What is the **simulated** probability of Wade starting with five coppers? *Hint: use your DataFrame `df_startingHands` for your calculation!*

# %%
P_fiveCoppers = len(df_startingHands[df_startingHands["coppers"] == 5]) / len(df_startingHands)
P_fiveCoppers
# Out:
# 0.0849

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: A Lucky Start ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 0.07 <= P_fiveCoppers and 0.1 >= P_fiveCoppers ), "You've calculated `P_fiveCoppers` incorrectly."
'''
NOTE: 
These boundary values were obtained by running 10,000 correct simulations and finding the max, min probability of ALL those runs. 
There is still a chance, albeit *extremely* low, that a student fails this test case with correct code. 
If the value is suspiciously close, try running all cells again. 
'''

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Sample Space
#
# **Q2: Observe the proportion of coppers to estates in each iteration of the simulation. What is the cause of this trend?**

# %% [markdown]
# *(✏️ There are more coppers compared to estates because it is more likely to draw a copper card based off the card deck having more than two times of copper than estate. ✏️)*

# %% [markdown]
# **Q3: What would happen to the simulated probability of having a starting hand of five coppers if we took out 2 estate cards from the starting deck (leaving 7 “coppers” and 1 “estate” in the starting deck)? Why?**

# %% [markdown]
# *(✏️ The probability will lower because we are drawing without replacement and after each draw of copper, the chances of drawing an estate will increase. Overall, compared to the deck that have 7 coppers, having only 5 will lower the chances of getting copper. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Images
#
# Up until now, we have used **organized, well-structured data** in DISCOVERY.  However, data can be found everywhere and, in this lab, we'll begin to explore the data that makes up an image.
#
# A computer represents an image as a 2D grid of **pixels** where each pixel is a single color.  Here is a tiny image **zoomed at 50x** that shows nine pixels:
#
# ![Color](./notebook-images/sample-50x.png)
#
# The actual image size of a 3 pixel by 3 pixel image is **really small** (here it is): ![sample image](./notebook-images/sample.png)
#
# We will need to use Python to help us process large images, but we will use the large image to understand an image!  For this lab, we have provided the function for you to load images as a DataFrame.
#
# - Make sure to `import DISCOVERY` to import the code specific for DISCOVERY
# - Then use `DISCOVERY.df_image("sample.png")` to load the image data into a DataFrame `df_pixels`

# %%
# Load the image into a DataFrame `df_pixels`:
import DISCOVERY
df_pixels = DISCOVERY.df_image("sample.png")
df_pixels
# Out:
#    x  y    r    g    b
# 0  0  0    0    0  255
# 1  0  1    0  255    0
# 2  0  2  255  255  255
# 3  1  0  255  255  255
# 4  1  1    0    0    0
# 5  1  2  255   85   46
# 6  2  0  255    0    0
# 7  2  1  255  255  255
# 8  2  2   19   41   75

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: Using Images ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df_pixels) == 9 ), "The length of your `df_pixels` should be 9 - there's 9 pixels in the sample.png!"
assert( len(df_pixels.columns.to_list() ) == 5 ), "There should be five columns in your `df_pixels`."
for col in ['x', 'y', 'r', 'g', 'b']:
    assert ( col in df_pixels ), f"Your `df_pixels` is missing the {col} column. Make sure you're using the `DISCOVERY.df_image()` function!"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Understanding the DataFrame
#
# In your DataFrame above, every pixel has five values:
# - An `x` value, for the **x** (horizontal) position, starting with `0` in the top-left
# - A `y` value, for the **y** (vertical) position, starting with `0` in the top-left
# - An `r` value, for the amount of **red** color in the image (`0` means no red, `255` means 100% red)
# - A `g` value, for the amount of **green** color in the image (`0` - `255`)
# - A `b` value, for the amount of **blue** color in the image (`0` - `255`)
#
# In the image above, the top-left cell is blue.  Let's see what that looks like in data:

# %%
df_pixels[ (df_pixels.x == 0) & (df_pixels.y == 0) ]
# Out:
#    x  y  r  g    b
# 0  0  0  0  0  255

# %% [markdown]
# ...the color value for `(x = 0, y = 0)` is all blue (`b = 255`) with no other colors added.  Moving to the right to `x == 1`:

# %%
df_pixels[ (df_pixels.x == 1) & (df_pixels.y == 0) ]
# Out:
#    x  y    r    g    b
# 3  1  0  255  255  255

# %% [markdown]
# ...the color value for `(x = 1, y = 0)` is all the colors (`r`, `g` and `b` are all `255`).  Since computers create colors with light ("additive colors"), the combination of all the colors makes a white color.

# %% [markdown]
# ## Finding all the white pixels
#
# Just above this section, you learned how a white pixel is represented in data.  Create a new DataFrame, `df_white`, that contains all of the white pixels in the sample image:

# %%
df_white = df_pixels[(df_pixels["r"] == 255) & (df_pixels["g"] == 255) & (df_pixels["b"] == 255)]
df_white
# Out:
#    x  y    r    g    b
# 2  0  2  255  255  255
# 3  1  0  255  255  255
# 7  2  1  255  255  255

# %% [markdown]
# ## Finding all the "primarily red" pixels
#
# Find all the pixels that are "primarily red", where a "primarily red" pixel has more red than green **AND** more red than blue.  Store all the "primarily red" pixels in the DataFrame `df_red`.

# %%
df_red = df_pixels[(df_pixels["r"] > df_pixels["g"]) & (df_pixels["r"] > df_pixels["b"])]
df_red
# Out:
#    x  y    r   g   b
# 5  1  2  255  85  46
# 6  2  0  255   0   0

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: Finding Pixels ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_white' in vars() ), "Make sure your DataFrame of white pixels is named `df_white`."
assert( 'df_red' in vars() ), "Make sure your DataFrame of red pixels is named `df_red`."
assert( len(df_white) == 3 ), "Your `df_white` does not contain all three white pixels in the sample image."
assert( (df_white['r'] == 255).all() and (df_white['g'] == 255).all() and (df_white['b'] == 255).all() ), "Your `df_white` contains non-white pixels."
assert( len(df_red) == 2 ), "Your `df_red` does not contain the two 'primarily red' pixels in the sample image."
assert( set(df_red['x'] + df_red['y']) == {2, 3} ), "Your `df_red` does not contain the two 'primarily red' pixels in the sample image."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: A Certain Area of Pixels
#
# **Q4: Looking at pixels of a certain color is interesting, but something else we can analyze with this DataFrame is a certain area of pixels! If we wanted to look at the color data in a 2x3 rectangle of pixels, how would you subset the above DataFrame to view that information?**

# %% [markdown]
# *(✏️ Select based on coordinates of the pixel. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 4: Images with your TAs and CAs
#
# Before your section, your TA -- with the help of the CAs -- picked an image for you to do analysis on!
#
# - Navigate to the image and save the image to your computer.
# - Place the image in the same folder as this lab (`lab_favorites`).
# - Load the image into a DataFrame `df`.

# %%
# Load the image your TA chose for you into a DataFrame:
df = DISCOVERY.df_image("fav.png")
df
# Out:
#           x    y    r    g    b
# 0         0    0  251  255  254
# 1         0    1  251  255  254
# 2         0    2  251  255  252
# 3         0    3  251  255  252
# 4         0    4  252  255  250
# ...     ...  ...  ...  ...  ...
# 326495  499  648  250  255  255
# 326496  499  649  249  254  255
# 326497  499  650  249  255  255
# 326498  499  651  249  255  255
# 326499  499  652  251  254  255
#
# [326500 rows x 5 columns]

# %% [markdown]
# ## Primary "Primary Color"
#
# Using the idea of "primary red" pixels, we will extend the idea to "primary red", "primary green", or "primary blue".  In the following three sections, find the **percentage of pixels** that are primarily red, green, and blue, storing in the **decimal variables** `percent_r`, `percent_g`, and `percent_b`:

# %%
# Find the percentage of primarily red pixels:
percent_r = len(df[(df["r"] > df["g"]) & (df["r"] > df["b"])]) / len(df)
percent_r
# Out:
# 0.2667687595712098

# %%
# Find the percentage of primarily green pixels:
percent_g = len(df[(df["g"] > df["r"]) & (df["g"] > df["b"])]) / len(df)
percent_g
# Out:
# 0.05913935681470138

# %%
# Find the percentage of primarily blue pixels:
percent_b = len(df[(df["b"] > df["g"]) & (df["b"] > df["r"])]) / len(df)
percent_r
percent_b
# Out:
# 0.5485359877488515

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: Finding Percentages ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( isinstance(percent_r, float) and isinstance(percent_g, float) and isinstance(percent_b, float) ), "Your percentages of r, g, b pixels should be decimal (float) variables."
assert( percent_r >= 0 and percent_r <= 1 ), "The percentage of red pixels must be between 0% and 100%."
assert( percent_g >= 0 and percent_g <= 1 ), "The percentage of green pixels must be between 0% and 100%."
assert( percent_b >= 0 and percent_b <= 1 ), "The percentage of blue pixels must be between 0% and 100%."
total = percent_r + percent_g + percent_b
assert( total >= 0 and total <= 1 ), "The total of your percentages should be between 0 and 1, not exceeding 100%!"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Average Color
#
# Finally, find the average color of the entire image.  The average color will have three components: the average red, the average green, and the average blue.

# %%
# Find the average red:
avg_red = df["r"].mean()
avg_red
# Out:
# 117.16342419601838

# %%
# Find the average green:
avg_green = df["g"].mean()
avg_green
# Out:
# 120.64886370597243

# %%
# Find the average blue:
avg_blue = df["b"].mean()
avg_blue
# Out:
# 130.6574946401225

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES: Finding Averages ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( isinstance(avg_red, float) and isinstance(avg_green, float) and isinstance(avg_blue, float) ), "Your average pixel color values should be decimal (float) variables."
assert( avg_red >= 0 and avg_red <= 255 ), "The average red value must be between 0 and 255."
assert( avg_green >= 0 and avg_green <= 255 ), "The average green value must be between 0 and 255."
assert( avg_blue >= 0 and avg_blue <= 255 ), "The average blue value must be between 0 and 255."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## See the Average Color
#
# Colors are presented in code as a tuple, `rgb(1, 2, 3)`.  Run the following code to see the average color represented as a tuple, and to see a Google search where you can view it yourself!

# %%
color = f"rgb({round(avg_red)}, {round(avg_green)}, {round(avg_blue)})"

print(f"Average color: {color}")
color = color.replace(" ", "")
print(f"See it on Google: https://www.google.com/search?q={color}&")
# Out:
# Average color: rgb(117, 121, 131)
# See it on Google: https://www.google.com/search?q=rgb(117,121,131)&

# %% [markdown]
# ### Analysis: Average Color
#
# **Q5: What is the most represented “color” in this average color? Why?**

# %% [markdown]
# *(✏️ Most represented color is blue because the backgound of the picture is blue. ✏️)*

# %% [markdown]
# **Q6: How might the average color of the image change if the proportion of colors in the tuple were different?**

# %% [markdown]
# *(✏️ If the tuple has more red or green, then the color tone of picture would also shift towards red or green. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
