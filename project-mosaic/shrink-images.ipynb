# %% [markdown]
# # Shrink Images for Project Mosaic
#
# If you use have many large images, this notebook contains the code to shrink your images to allow the mosaic to run quicker!
#
# - Run both of the below cells to shrink all your images.
# - Make sure your file folder is correct in the variables below:

# %%
# What folder contains your tile images?
tileImageFolder = "pictures"

# What is the size of your final, smaller tile images?
# - Your image will be resized to `tileImageDimension` x `tileImageDimension`
tileImageDimension = 32

# What is the new folder for your smaller tile images?
smallTileImageFolder = f"{tileImageFolder}-small"

# %%
import DISCOVERY
from PIL import Image
import os

os.makedirs(smallTileImageFolder, exist_ok=True)

for fileName in os.listdir(tileImageFolder):
  fullPath = os.path.join(tileImageFolder, fileName)
  if os.path.isfile(fullPath) and DISCOVERY.isImageFile(fullPath):
    print(f"Shrinking {fullPath}...")
    image = Image.open(fullPath)
    width, height = image.size
    dimension = min(width, height)
    image = image.crop((0, 0, dimension, dimension))
    image = image.resize((tileImageDimension, tileImageDimension), resample=Image.Resampling.LANCZOS)
    image.save(os.path.join(smallTileImageFolder, fileName))

tada = "\N{PARTY POPPER}"
print()
print(f"{tada} SHRINK COMPLETE!")
print(f"- All image files in \"{tileImageFolder}\" are now {tileImageDimension}px x {tileImageDimension}px and saved in \"{smallTileImageFolder}\".")
print(f"- Use \"{smallTileImageFolder}\" as your tile image folder to run the mosaic creation much faster!")
# Out:
# Shrinking pictures/IMG_3643.jpg...
# Shrinking pictures/IMG_2978.jpg...
# Shrinking pictures/IMG_2987.jpg...
# Shrinking pictures/IMG_2986.jpg...
# Shrinking pictures/IMG_3332.jpg...
# Shrinking pictures/IMG_2979.jpg...
# Shrinking pictures/IMG_3642.jpg...
# Shrinking pictures/IMG_3640.jpg...
# Shrinking pictures/IMG_3318.jpg...
# Shrinking pictures/IMG_2984.jpg...
# Shrinking pictures/IMG_3330.jpg...
# Shrinking pictures/IMG_3331.jpg...
# Shrinking pictures/IMG_2985.jpg...
# Shrinking pictures/IMG_3319.jpg...
# Shrinking pictures/IMG_3641.jpg...
# Shrinking pictures/IMG_2981.jpg...
# Shrinking pictures/IMG_3321.jpg...
# Shrinking pictures/IMG_2980.jpg...
# Shrinking pictures/IMG_3320.jpg...
# Shrinking pictures/IMG_2982.jpg...
# Shrinking pictures/IMG_2983.jpg...
# Shrinking pictures/IMG_3218.jpg...
# Shrinking pictures/IMG_3813.jpg...
# Shrinking pictures/IMG_3393.jpg...
# Shrinking pictures/IMG_3392.jpg...
# Shrinking pictures/IMG_3812.jpg...
# Shrinking pictures/IMG_3219.jpg...
# Shrinking pictures/IMG_3019.jpg...
# Shrinking pictures/IMG_3810.jpg...
# Shrinking pictures/IMG_3838.jpg...
# Shrinking pictures/IMG_3390.jpg...
# Shrinking pictures/IMG_3391.jpg...
# Shrinking pictures/IMG_3811.jpg...
# Shrinking pictures/IMG_3018.jpg...
# Shrinking pictures/IMG_3222.jpg...
# Shrinking pictures/IMG_3785.jpg...
# Shrinking pictures/IMG_3008.jpg...
# Shrinking pictures/IMG_3829.jpg...
# Shrinking pictures/IMG_3815.jpg...
# Shrinking pictures/IMG_3395.jpg...
# Shrinking pictures/IMG_3394.jpg...
# Shrinking pictures/IMG_3814.jpg...
# Shrinking pictures/IMG_3828.jpg...
# Shrinking pictures/IMG_3009.jpg...
# Shrinking pictures/IMG_3784.jpg...
# Shrinking pictures/IMG_3221.jpg...
# Shrinking pictures/IMG_3786.jpg...
# Shrinking pictures/IMG_3816.jpg...
# Shrinking pictures/IMG_3396.jpg...
# Shrinking pictures/IMG_3397.jpg...
# Shrinking pictures/IMG_3817.jpg...
# Shrinking pictures/IMG_3022.jpg...
# Shrinking pictures/IMG_3787.jpg...
# Shrinking pictures/IMG_3220.jpg...
# Shrinking pictures/IMG_3007.jpg...
# Shrinking pictures/IMG_3832.jpg...
# Shrinking pictures/IMG_3826.jpg...
# Shrinking pictures/IMG_3827.jpg...
# Shrinking pictures/IMG_3833.jpg...
# Shrinking pictures/IMG_3006.jpg...
# Shrinking pictures/IMG_3010.jpg...
# Shrinking pictures/IMG_3004.jpg...
# Shrinking pictures/IMG_3825.jpg...
# Shrinking pictures/IMG_3831.jpg...
# Shrinking pictures/IMG_3819.jpg...
# Shrinking pictures/IMG_3818.jpg...
# Shrinking pictures/IMG_3830.jpg...
# Shrinking pictures/IMG_3824.jpg...
# Shrinking pictures/IMG_3005.jpg...
# Shrinking pictures/IMG_3788.jpg...
# Shrinking pictures/IMG_3015.jpg...
# Shrinking pictures/IMG_3001.jpg...
# Shrinking pictures/IMG_3820.jpg...
# Shrinking pictures/IMG_3834.jpg...
# Shrinking pictures/IMG_3388.jpg...
# Shrinking pictures/IMG_3389.jpg...
# Shrinking pictures/IMG_3835.jpg...
# Shrinking pictures/IMG_3821.jpg...
# Shrinking pictures/IMG_3809.jpg...
# Shrinking pictures/IMG_3002.jpg...
# Shrinking pictures/IMG_3016.jpg...
# Shrinking pictures/IMG_3837.jpg...
# Shrinking pictures/IMG_3823.jpg...
# Shrinking pictures/IMG_3639.jpg...
# Shrinking pictures/IMG_3822.jpg...
# Shrinking pictures/IMG_3836.jpg...
# Shrinking pictures/IMG_3003.jpg...
# Shrinking pictures/IMG_3313.jpg...
# Shrinking pictures/IMG_3846.jpg...
# Shrinking pictures/IMG_3314.jpg...
# Shrinking pictures/IMG_3328.jpg...
# Shrinking pictures/IMG_3329.jpg...
# Shrinking pictures/IMG_3315.jpg...
# Shrinking pictures/IMG_3317.jpg...
# Shrinking pictures/IMG_3316.jpg...
#
# 🎉 SHRINK COMPLETE!
# - All image files in "pictures" are now 32px x 32px and saved in "pictures-small".
# - Use "pictures-small" as your tile image folder to run the mosaic creation much faster!
